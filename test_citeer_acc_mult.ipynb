# %%
import dgl
from Datasets.NodeClassification.Citeseer import Citeseer
from GraphSummarizers.Coarsener.HeteroCoarsener import HeteroCoarsener
import torch
import numpy as np
from Models.GNNs.HGCN import HeteroGCNCiteer
torch.cuda.empty_cache()

# %%
dataset = Citeseer() 
original_graph = dataset.load_graph()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
original_graph = original_graph.to(device=device)
print(device)
# Out:
#   NumNodes: 3327
#   NumEdges: 9228
#   NumFeats: 3703
#   NumClasses: 6
#   NumTrainingSamples: 120
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# cuda

# %%
# 2. Utility: create train/val/test indices and corresponding labels

def get_splits_and_labels(hetero_graph, ntype='paper',train_ratio=0.1, val_ratio=0.1, test_ratio=0.8, random_state=5):
    """
    Extract train/val/test node indices and their labels for a given node type.

    Returns
    # -------
    dict
        {
          'train_idx': LongTensor,
          'val_idx': LongTensor,
          'test_idx': LongTensor,
          'train_labels': LongTensor,
          'val_labels': LongTensor,
          'test_labels': LongTensor
        }
    """
    np.random.seed(random_state)
    indices = np.random.permutation(hetero_graph.nodes[ntype].data["feat"].size()[0])
    num_papers =hetero_graph.nodes[ntype].data["feat"].size()[0]
    
    train_size = int(num_papers * train_ratio)
    val_size = int(num_papers * val_ratio)
    
    
    train_indices = indices[:train_size]
    val_indices = indices[train_size:train_size + val_size]
    test_indices = indices[train_size + val_size:]
    
    train_mask = torch.zeros(num_papers, dtype=torch.bool, device=device)
    val_mask = torch.zeros(num_papers, dtype=torch.bool, device=device)
    test_mask = torch.zeros(num_papers, dtype=torch.bool, device=device)
    
    train_mask[train_indices] = True
    val_mask[val_indices] = True
    test_mask[test_indices] = True
    
    # Add masks to hetero_data
    hetero_graph.nodes[ntype].data["train_mask"] = train_mask
    hetero_graph.nodes[ntype].data["val_mask"] = val_mask
    hetero_graph.nodes[ntype].data["test_mask"] = test_mask
    
    labels = hetero_graph.nodes[ntype].data['label']
    train_mask = hetero_graph.nodes[ntype].data['train_mask']
    val_mask = hetero_graph.nodes[ntype].data['val_mask']
    test_mask = hetero_graph.nodes[ntype].data['test_mask']

    train_idx = train_mask.nonzero(as_tuple=True)[0]
    val_idx = val_mask.nonzero(as_tuple=True)[0]
    test_idx = test_mask.nonzero(as_tuple=True)[0]

    return {
        'train_idx': train_idx,
        'val_idx': val_idx,
        'test_idx': test_idx,
        'train_labels': labels[train_idx],
        'val_labels': labels[val_idx],
        'test_labels': labels[test_idx]
    }

# Example usage:
#data_splits_orig = get_splits_and_labels(original_graph)

# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

def run_multiple_experiments(original_graph, coarsend_graph, mapping, get_splits_and_labels, model_class, num_runs=5, epochs=150):
    target_node_type = "paper"
    
    original_accuracies = []
    coarsened_accuracies = []
    inverted_accuracies = []
    

    for run in range(num_runs):
        print(f"\n========== Run {run+1} ==========\n")

        # Get new splits
        splits_orig = get_splits_and_labels(original_graph, random_state=run)
        splits_coar = get_splits_and_labels(coarsend_graph, random_state=run)

        train_idx_orig = splits_orig['train_idx']
        val_idx_orig = splits_orig['val_idx']
        test_idx_orig = splits_orig['test_idx']
        labels_orig = original_graph.nodes[target_node_type].data['label']

        train_idx_coar = splits_coar['train_idx']
        val_idx_coar = splits_coar['val_idx']
        test_idx_coar = splits_coar['test_idx']
        labels_coar = coarsend_graph.nodes[target_node_type].data['label']

        feat_orig = {target_node_type: original_graph.nodes[target_node_type].data['feat']}
        feat_coar = {target_node_type: coarsend_graph.nodes[target_node_type].data['feat']}

        model_original = model_class(in_dim=feat_orig[target_node_type].shape[1], hidden_dim=64,
                                     out_dim=6, rel_names=original_graph.etypes)
        optimizer_original = torch.optim.Adam(model_original.parameters(), lr=0.01, weight_decay=5e-4)

        model_coarsened = model_original.to(device=device)
        
        model_coarsened = model_class(in_dim=feat_coar[target_node_type].shape[1], hidden_dim=64,
                                      out_dim=6, rel_names=original_graph.etypes)
        model_coarsened = model_coarsened.to(device=device)
        optimizer_coarsened = torch.optim.Adam(model_coarsened.parameters(), lr=0.01, weight_decay=5e-4)

        def train(model, graph, feats, labels, train_idx, optimizer):
            model.train()
            optimizer.zero_grad()
            logits = model(graph, feats)[target_node_type]
            loss = F.cross_entropy(logits[train_idx], labels[train_idx])
            loss.backward()
            optimizer.step()
            return loss.item()

        def test(model, graph, feats, labels, val_idx):
            model.eval()
            with torch.no_grad():
                logits = model(graph, feats)[target_node_type]
                preds = logits.argmax(dim=1)
                correct = (preds[val_idx] == labels[val_idx]).sum().item()
                return correct / val_idx.shape[0], preds

        def apply_inversion_mapping(coarsened_pred, inversion_map, original_labels, test_mask):
            correct_count = 0
            total_count = 0
            for orig_node, coarsened_node in inversion_map.items():
                if coarsened_node not in test_mask:
                    continue
                coarse_pred = coarsened_pred[coarsened_node]
                orig_label = original_labels[orig_node]
                if coarse_pred == orig_label:
                    correct_count += 1
                total_count += 1
            return correct_count / total_count if total_count > 0 else 0

        for epoch in range(epochs):
            train(model_original, original_graph, feat_orig, labels_orig, train_idx_orig, optimizer_original)
            train(model_coarsened, coarsend_graph, feat_coar, labels_coar, train_idx_coar, optimizer_coarsened)

        # Final test
        original_acc, _ = test(model_original, original_graph, feat_orig, labels_orig, val_idx_orig)
        coarsened_acc, preds = test(model_coarsened, original_graph, feat_orig, labels_orig, val_idx_orig)
        _, preds = test(model_original, coarsend_graph, feat_coar, labels_coar, val_idx_coar)
        
        inverted_acc = apply_inversion_mapping(preds, mapping, labels_orig, test_idx_coar)

        print(f"Original Graph Accuracy:   {original_acc:.4f}")
        print(f"Coarsened Graph Accuracy:  {coarsened_acc:.4f}")
        print(f"Inverted Coarsened Accuracy: {inverted_acc:.4f}")

        original_accuracies.append(original_acc)
        coarsened_accuracies.append(coarsened_acc)
        inverted_accuracies.append(inverted_acc)

    # Compute stats
    def summarize(name, values):
        values = np.array(values)
        print(f"\n{name}:")
        print(f"  Mean: {values.mean():.4f}")
        print(f"  Std:  {values.std():.4f}")
        return values

    orig_vals = summarize("Original Graph Accuracy", original_accuracies)
    coar_vals = summarize("Coarsened Graph Accuracy", coarsened_accuracies)
    inv_vals = summarize("Inverted Accuracy", inverted_accuracies)

    # Plot bar chart
    labels = [f"Run {i+1}" for i in range(num_runs)]
    x = np.arange(num_runs)
    width = 0.25

    plt.figure(figsize=(10, 5))
    plt.bar(x - width, orig_vals, width, label='Original')
    plt.bar(x, coar_vals, width, label='Coarsened')
    plt.bar(x + width, inv_vals, width, label='Inverted')
    plt.xlabel('Run')
    plt.ylabel('Accuracy')
    plt.title('Accuracy Across Multiple Runs')
    plt.xticks(x, labels)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
coarsener =  HeteroCoarsener(None,original_graph, 0.1, num_nearest_per_etype=10, num_nearest_neighbors=10,pairs_per_level=10, is_neighboring_h=True, is_adj=True) #, device="cpu" 
torch.cuda.empty_cache()
#coarsener = HeteroCoarsener(None,original_graph, 0.1, num_nearest_per_etype=30, num_nearest_neighbors=30,pairs_per_level=10, is_neighboring_h= False) #
coarsener.init_step()
isNewMerges = True
for i in range(10):
    if not isNewMerges:
        break
    print("--------- step: " , i , "---------" )
    isNewMerges = coarsener.iteration_step()

coarsend_graph = coarsener.get_coarsend_graph()
#coarsend_graph = coarsend_graph.cpu()
mapping = coarsener.get_mapping("paper")
labels = coarsener._get_labels(mapping, "paper")
coarsend_graph.nodes["paper"].data["label"] = torch.tensor([labels[i] for i in range(len(labels))], device=device)
print("ratio", coarsend_graph.num_nodes()/ original_graph.num_nodes() ) 

run_multiple_experiments(
    original_graph=original_graph,
    coarsend_graph=coarsend_graph,
    mapping=mapping,
    get_splits_and_labels=get_splits_and_labels,
    model_class=HeteroGCNCiteer,  # or ImprovedHeteroGNN if needed
    num_runs=5,
    epochs=150
)
# Out:
# /storage/scratch/0994359/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   deg_out = torch.tensor(self.node_degrees[etype]['out'], device=self.device) + 1.0
# /storage/scratch/0994359/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   deg_in  = torch.tensor(self.node_degrees[etype]['in'], device=self.device)  + 1.0
# _create_h_spatial_rgcn 0.0015866756439208984
# _init_costs 0.0005779266357421875
# _get_union 1.667452335357666
# _costs_of_merges 3.6635079383850098
# _init_merge_graph 0.0012214183807373047
# _find_lowest_cost_edges 0.0005710124969482422
# --------- step:  0 ---------
# _merge_nodes 0.00423121452331543
# longer time -0.011801719665527344
# longer time -0.0113525390625
# _update_merge_graph 0.03877568244934082
# _find_lowest_cost_edges 0.0031783580780029297
# --------- step:  1 ---------
# _merge_nodes 0.004055500030517578
# longer time -0.008399009704589844
# longer time -0.008278846740722656
# _update_merge_graph 0.030922412872314453
# _find_lowest_cost_edges 0.0022890567779541016
# --------- step:  2 ---------
# _merge_nodes 0.003937959671020508
# longer time -0.01198267936706543
# longer time -0.011433839797973633
# _update_merge_graph 0.04597830772399902
# _find_lowest_cost_edges 0.0021867752075195312
# --------- step:  3 ---------
# _merge_nodes 0.0041196346282958984
# longer time -0.00948190689086914
# longer time -0.009503364562988281
# _update_merge_graph 0.03427624702453613
# /storage/scratch/0994359/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:832: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   node1s = torch.tensor(node1s, dtype=torch.long, device=self.device)
# /storage/scratch/0994359/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:833: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   node2s = torch.tensor(node2s, dtype=torch.long, device=self.device)
# _find_lowest_cost_edges 0.0022208690643310547
# --------- step:  4 ---------
# _merge_nodes 0.004041910171508789
# longer time -0.01151895523071289
# longer time -0.01103973388671875
# _update_merge_graph 0.03718900680541992
# _find_lowest_cost_edges 0.0030198097229003906
# --------- step:  5 ---------
# _merge_nodes 0.0049517154693603516
# longer time -0.008333921432495117
# longer time -0.008086204528808594
# _update_merge_graph 0.0311431884765625
# _find_lowest_cost_edges 0.002192258834838867
# --------- step:  6 ---------
# _merge_nodes 0.004015684127807617
# longer time -0.008197307586669922
# longer time -0.008041858673095703
# _update_merge_graph 0.03030109405517578
# _find_lowest_cost_edges 0.0021588802337646484
# --------- step:  7 ---------
# _merge_nodes 0.005178689956665039
# longer time -0.008151054382324219
# longer time -0.009422540664672852
# _update_merge_graph 0.03176116943359375
# _find_lowest_cost_edges 0.0029783248901367188
# --------- step:  8 ---------
# _merge_nodes 0.005044460296630859
# longer time -0.008135557174682617
# longer time -0.00799107551574707
# _update_merge_graph 0.031113147735595703
# _find_lowest_cost_edges 0.002253293991088867
# --------- step:  9 ---------
# _merge_nodes 0.00525665283203125
# longer time -0.008121252059936523
# longer time -0.009531974792480469
# _update_merge_graph 0.03157520294189453
# _find_lowest_cost_edges 0.0021386146545410156
# ratio 0.981965734896303
#
# ========== Run 1 ==========
#
# Original Graph Accuracy:   0.6777
# Coarsened Graph Accuracy:  0.6928
# Inverted Coarsened Accuracy: 0.6784
#
# ========== Run 2 ==========
#
# Original Graph Accuracy:   0.7018
# Coarsened Graph Accuracy:  0.7380
# Inverted Coarsened Accuracy: 0.6962
#
# ========== Run 3 ==========
#
# Original Graph Accuracy:   0.7139
# Coarsened Graph Accuracy:  0.7108
# Inverted Coarsened Accuracy: 0.6898
#
# ========== Run 4 ==========
#
# Original Graph Accuracy:   0.6747
# Coarsened Graph Accuracy:  0.7229
# Inverted Coarsened Accuracy: 0.6767
#
# ========== Run 5 ==========
#
# Original Graph Accuracy:   0.6687
# Coarsened Graph Accuracy:  0.6928
# Inverted Coarsened Accuracy: 0.6797
#
# Original Graph Accuracy:
#   Mean: 0.6873
#   Std:  0.0174
#
# Coarsened Graph Accuracy:
#   Mean: 0.7114
#   Std:  0.0175
#
# Inverted Accuracy:
#   Mean: 0.6842
#   Std:  0.0076

# %%
coarsener = HeteroCoarsener(None,original_graph, 0.1, num_nearest_per_etype=100, num_nearest_neighbors=100,pairs_per_level=10) #
coarsener.init_step()
isNewMerges = True
for i in range(1000):
    if not isNewMerges:
        break
    print("--------- step: " , i , "---------" )
    isNewMerges = coarsener.iteration_step()

coarsend_graph = coarsener.get_coarsend_graph()
coarsend_graph = coarsend_graph.cpu()
mapping = coarsener.get_mapping("paper")
labels = coarsener._get_labels(mapping, "paper")
coarsend_graph.nodes["paper"].data["label"] = torch.tensor([labels[i] for i in range(len(labels))])
print("ratio", coarsend_graph.num_nodes()/ original_graph.num_nodes() ) 

run_multiple_experiments(
    original_graph=original_graph,
    coarsend_graph=coarsend_graph,
    mapping=mapping,
    get_splits_and_labels=get_splits_and_labels,
    model_class=HeteroGCNCiteer,  # or ImprovedHeteroGNN if needed
    num_runs=5,
    epochs=150
)
# Out:
# /home/robin/thesis/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   deg_out = torch.tensor(self.node_degrees[etype]['out'], device=self.device) + 1.0
# /home/robin/thesis/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   deg_in  = torch.tensor(self.node_degrees[etype]['in'], device=self.device)  + 1.0
# _create_h_spatial_rgcn 0.006117582321166992
# _init_costs 0.5184230804443359
# _get_union 1.786280632019043
# _costs_of_merges 4.9096620082855225
# _init_merge_graph 0.11651420593261719
# _find_lowest_cost_edges 0.00853419303894043
# --------- step:  0 ---------
# _merge_nodes 0.018207788467407227
# /home/robin/thesis/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:861: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   node1s = torch.tensor(node1s, dtype=torch.long, device=self.device)
# /home/robin/thesis/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:862: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   node2s = torch.tensor(node2s, dtype=torch.long, device=self.device)
# _update_merge_graph 0.07761597633361816
# _find_lowest_cost_edges 0.00998234748840332
# --------- step:  1 ---------
# _merge_nodes 0.02245187759399414
# _update_merge_graph 0.07283496856689453
# _find_lowest_cost_edges 0.010074138641357422
# --------- step:  2 ---------
# _merge_nodes 0.04828071594238281
# _update_merge_graph 0.07335495948791504
# _find_lowest_cost_edges 0.009045600891113281
# --------- step:  3 ---------
# _merge_nodes 0.018459796905517578
# _update_merge_graph 0.07345247268676758
# _find_lowest_cost_edges 0.010666847229003906
# --------- step:  4 ---------
# _merge_nodes 0.023074865341186523
# _update_merge_graph 0.07170987129211426
# _find_lowest_cost_edges 0.010381221771240234
# --------- step:  5 ---------
# _merge_nodes 0.014411687850952148
# _update_merge_graph 0.0589902400970459
# _find_lowest_cost_edges 0.011609792709350586
# --------- step:  6 ---------
# _merge_nodes 0.011324644088745117
# _update_merge_graph 0.06532883644104004
# _find_lowest_cost_edges 0.006737470626831055
# --------- step:  7 ---------
# _merge_nodes 0.025618553161621094
# _update_merge_graph 0.0780649185180664
# _find_lowest_cost_edges 0.007620811462402344
# --------- step:  8 ---------
# _merge_nodes 0.0245363712310791
# _update_merge_graph 0.08514714241027832
# _find_lowest_cost_edges 0.007962703704833984
# --------- step:  9 ---------
# _merge_nodes 0.025677919387817383
# _update_merge_graph 0.07950019836425781
# _find_lowest_cost_edges 0.007020235061645508
# --------- step:  10 ---------
# _merge_nodes 0.024809598922729492
# _update_merge_graph 0.07749223709106445
# _find_lowest_cost_edges 0.009211540222167969
# --------- step:  11 ---------
# _merge_nodes 0.032883644104003906
# _update_merge_graph 0.05862855911254883
# _find_lowest_cost_edges 0.01095128059387207
# --------- step:  12 ---------
# _merge_nodes 0.014307022094726562
# _update_merge_graph 0.08403730392456055
# _find_lowest_cost_edges 0.005054473876953125
# --------- step:  13 ---------
# _merge_nodes 0.027384281158447266
# _update_merge_graph 0.08741521835327148
# _find_lowest_cost_edges 0.0072934627532958984
# --------- step:  14 ---------
# _merge_nodes 0.031099796295166016
# _update_merge_graph 0.07790613174438477
# _find_lowest_cost_edges 0.008610725402832031
# --------- step:  15 ---------
# _merge_nodes 0.023680448532104492
# _update_merge_graph 0.07942557334899902
# _find_lowest_cost_edges 0.007109165191650391
# --------- step:  16 ---------
# _merge_nodes 0.019148826599121094
# _update_merge_graph 0.07885909080505371
# _find_lowest_cost_edges 0.009618997573852539
# --------- step:  17 ---------
# _merge_nodes 0.026110410690307617
# _update_merge_graph 0.07392621040344238
# _find_lowest_cost_edges 0.008997678756713867
# --------- step:  18 ---------
# _merge_nodes 0.033997297286987305
# _update_merge_graph 0.0686485767364502
# _find_lowest_cost_edges 0.006880283355712891
# --------- step:  19 ---------
# _merge_nodes 0.031831979751586914
# _update_merge_graph 0.08226490020751953
# _find_lowest_cost_edges 0.008835554122924805
# --------- step:  20 ---------
# _merge_nodes 0.017368078231811523
# _update_merge_graph 0.07238149642944336
# _find_lowest_cost_edges 0.007528543472290039
# --------- step:  21 ---------
# _merge_nodes 0.029697895050048828
# _update_merge_graph 0.08733439445495605
# _find_lowest_cost_edges 0.0050449371337890625
# --------- step:  22 ---------
# _merge_nodes 0.033117055892944336
# _update_merge_graph 0.07147431373596191
# _find_lowest_cost_edges 0.007799863815307617
# --------- step:  23 ---------
# _merge_nodes 0.02316117286682129
# _update_merge_graph 0.08316421508789062
# _find_lowest_cost_edges 0.006223917007446289
# --------- step:  24 ---------
# _merge_nodes 0.022881269454956055
# _update_merge_graph 0.06464767456054688
# _find_lowest_cost_edges 0.008047342300415039
# --------- step:  25 ---------
# _merge_nodes 0.02204132080078125
# _update_merge_graph 0.07383275032043457
# _find_lowest_cost_edges 0.0066525936126708984
# --------- step:  26 ---------
# _merge_nodes 0.023629188537597656
# _update_merge_graph 0.07110857963562012
# _find_lowest_cost_edges 0.008891820907592773
# --------- step:  27 ---------
# _merge_nodes 0.02254796028137207
# _update_merge_graph 0.08103370666503906
# _find_lowest_cost_edges 0.006705760955810547
# --------- step:  28 ---------
# _merge_nodes 0.03349590301513672
# _update_merge_graph 0.07335233688354492
# _find_lowest_cost_edges 0.007432699203491211
# --------- step:  29 ---------
# _merge_nodes 0.027724027633666992
# _update_merge_graph 0.08697247505187988
# _find_lowest_cost_edges 0.004027128219604492
# --------- step:  30 ---------
# _merge_nodes 0.02139115333557129
# _update_merge_graph 0.05526399612426758
# _find_lowest_cost_edges 0.0092010498046875
# --------- step:  31 ---------
# _merge_nodes 0.011319637298583984
# _update_merge_graph 0.056444406509399414
# _find_lowest_cost_edges 0.008853435516357422
# --------- step:  32 ---------
# _merge_nodes 0.01373434066772461
# _update_merge_graph 0.05052924156188965
# _find_lowest_cost_edges 0.009136199951171875
# --------- step:  33 ---------
# _merge_nodes 0.01219630241394043
# _update_merge_graph 0.0501861572265625
# _find_lowest_cost_edges 0.008985042572021484
# --------- step:  34 ---------
# _merge_nodes 0.012909889221191406
# _update_merge_graph 0.051991939544677734
# _find_lowest_cost_edges 0.008953332901000977
# --------- step:  35 ---------
# _merge_nodes 0.010603189468383789
# _update_merge_graph 0.06149482727050781
# _find_lowest_cost_edges 0.00750422477722168
# --------- step:  36 ---------
# _merge_nodes 0.023788928985595703
# _update_merge_graph 0.058025360107421875
# _find_lowest_cost_edges 0.008345842361450195
# --------- step:  37 ---------
# _merge_nodes 0.014592647552490234
# _update_merge_graph 0.05256485939025879
# _find_lowest_cost_edges 0.007803201675415039
# --------- step:  38 ---------
# _merge_nodes 0.017513275146484375
# _update_merge_graph 0.05339479446411133
# _find_lowest_cost_edges 0.009122848510742188
# --------- step:  39 ---------
# _merge_nodes 0.011214017868041992
# _update_merge_graph 0.04911541938781738
# _find_lowest_cost_edges 0.00848698616027832
# --------- step:  40 ---------
# _merge_nodes 0.011722326278686523
# _update_merge_graph 0.05555295944213867
# _find_lowest_cost_edges 0.007550954818725586
# --------- step:  41 ---------
# _merge_nodes 0.03418922424316406
# _update_merge_graph 0.050817251205444336
# _find_lowest_cost_edges 0.00813746452331543
# --------- step:  42 ---------
# _merge_nodes 0.01609516143798828
# _update_merge_graph 0.04964113235473633
# _find_lowest_cost_edges 0.00844264030456543
# --------- step:  43 ---------
# _merge_nodes 0.01310586929321289
# _update_merge_graph 0.04993581771850586
# _find_lowest_cost_edges 0.008784294128417969
# --------- step:  44 ---------
# _merge_nodes 0.010871410369873047
# _update_merge_graph 0.04732108116149902
# _find_lowest_cost_edges 0.008756875991821289
# --------- step:  45 ---------
# _merge_nodes 0.01084446907043457
# _update_merge_graph 0.05205273628234863
# _find_lowest_cost_edges 0.0074825286865234375
# --------- step:  46 ---------
# _merge_nodes 0.01573967933654785
# _update_merge_graph 0.054189205169677734
# _find_lowest_cost_edges 0.00760650634765625
# --------- step:  47 ---------
# _merge_nodes 0.012627124786376953
# _update_merge_graph 0.05100393295288086
# _find_lowest_cost_edges 0.00847625732421875
# --------- step:  48 ---------
# _merge_nodes 0.020580530166625977
# _update_merge_graph 0.07103419303894043
# _find_lowest_cost_edges 0.007584810256958008
# --------- step:  49 ---------
# _merge_nodes 0.02854609489440918
# _update_merge_graph 0.07566142082214355
# _find_lowest_cost_edges 0.005769968032836914
# --------- step:  50 ---------
# _merge_nodes 0.04805278778076172
# _update_merge_graph 0.056398630142211914
# _find_lowest_cost_edges 0.007925748825073242
# --------- step:  51 ---------
# _merge_nodes 0.013658285140991211
# _update_merge_graph 0.06475496292114258
# _find_lowest_cost_edges 0.005433797836303711
# --------- step:  52 ---------
# _merge_nodes 0.014395713806152344
# _update_merge_graph 0.04940366744995117
# _find_lowest_cost_edges 0.008186817169189453
# --------- step:  53 ---------
# _merge_nodes 0.013071537017822266
# _update_merge_graph 0.05141806602478027
# _find_lowest_cost_edges 0.0070209503173828125
# --------- step:  54 ---------
# _merge_nodes 0.020951509475708008
# _update_merge_graph 0.07923150062561035
# _find_lowest_cost_edges 0.0027132034301757812
# --------- step:  55 ---------
# _merge_nodes 0.01820206642150879
# _update_merge_graph 0.061791419982910156
# _find_lowest_cost_edges 0.006935596466064453
# --------- step:  56 ---------
# _merge_nodes 0.01885080337524414
# _update_merge_graph 0.060399770736694336
# _find_lowest_cost_edges 0.007550954818725586
# --------- step:  57 ---------
# _merge_nodes 0.015817880630493164
# _update_merge_graph 0.049359798431396484
# _find_lowest_cost_edges 0.0074350833892822266
# --------- step:  58 ---------
# _merge_nodes 0.014370918273925781
# _update_merge_graph 0.05000042915344238
# _find_lowest_cost_edges 0.00806283950805664
# --------- step:  59 ---------
# _merge_nodes 0.014193296432495117
# _update_merge_graph 0.06551647186279297
# _find_lowest_cost_edges 0.0047910213470458984
# --------- step:  60 ---------
# _merge_nodes 0.018374204635620117
# _update_merge_graph 0.08096671104431152
# _find_lowest_cost_edges 0.007430315017700195
# --------- step:  61 ---------
# _merge_nodes 0.03594613075256348
# _update_merge_graph 0.08364367485046387
# _find_lowest_cost_edges 0.005438089370727539
# --------- step:  62 ---------
# _merge_nodes 0.02033400535583496
# _update_merge_graph 0.057703495025634766
# _find_lowest_cost_edges 0.0076847076416015625
# --------- step:  63 ---------
# _merge_nodes 0.01703786849975586
# _update_merge_graph 0.06800580024719238
# _find_lowest_cost_edges 0.006595134735107422
# --------- step:  64 ---------
# _merge_nodes 0.014993667602539062
# _update_merge_graph 0.05239105224609375
# _find_lowest_cost_edges 0.007944822311401367
# --------- step:  65 ---------
# _merge_nodes 0.015499591827392578
# _update_merge_graph 0.047158241271972656
# _find_lowest_cost_edges 0.007905006408691406
# --------- step:  66 ---------
# _merge_nodes 0.016076087951660156
# _update_merge_graph 0.05039644241333008
# _find_lowest_cost_edges 0.007160186767578125
# --------- step:  67 ---------
# _merge_nodes 0.025526046752929688
# _update_merge_graph 0.060208797454833984
# _find_lowest_cost_edges 0.00655674934387207
# --------- step:  68 ---------
# _merge_nodes 0.019804000854492188
# _update_merge_graph 0.054788827896118164
# _find_lowest_cost_edges 0.0077474117279052734
# --------- step:  69 ---------
# _merge_nodes 0.015746116638183594
# _update_merge_graph 0.04924798011779785
# _find_lowest_cost_edges 0.007673978805541992
# --------- step:  70 ---------
# _merge_nodes 0.015120744705200195
# _update_merge_graph 0.05319643020629883
# _find_lowest_cost_edges 0.007288932800292969
# --------- step:  71 ---------
# _merge_nodes 0.0169832706451416
# _update_merge_graph 0.058020830154418945
# _find_lowest_cost_edges 0.007218837738037109
# --------- step:  72 ---------
# _merge_nodes 0.018347740173339844
# _update_merge_graph 0.06045198440551758
# _find_lowest_cost_edges 0.005288600921630859
# --------- step:  73 ---------
# _merge_nodes 0.022478103637695312
# _update_merge_graph 0.059923410415649414
# _find_lowest_cost_edges 0.005967855453491211
# --------- step:  74 ---------
# _merge_nodes 0.014605522155761719
# _update_merge_graph 0.047420501708984375
# _find_lowest_cost_edges 0.0069980621337890625
# --------- step:  75 ---------
# _merge_nodes 0.011700153350830078
# _update_merge_graph 0.04930233955383301
# _find_lowest_cost_edges 0.007180690765380859
# --------- step:  76 ---------
# _merge_nodes 0.015949010848999023
# _update_merge_graph 0.05180525779724121
# _find_lowest_cost_edges 0.006265878677368164
# --------- step:  77 ---------
# _merge_nodes 0.0232388973236084
# _update_merge_graph 0.04708361625671387
# _find_lowest_cost_edges 0.007838249206542969
# --------- step:  78 ---------
# _merge_nodes 0.013027429580688477
# _update_merge_graph 0.0695197582244873
# _find_lowest_cost_edges 0.00461578369140625
# --------- step:  79 ---------
# _merge_nodes 0.015613555908203125
# _update_merge_graph 0.050681352615356445
# _find_lowest_cost_edges 0.007389545440673828
# --------- step:  80 ---------
# _merge_nodes 0.014070272445678711
# _update_merge_graph 0.050810813903808594
# _find_lowest_cost_edges 0.005384206771850586
# --------- step:  81 ---------
# _merge_nodes 0.017340660095214844
# _update_merge_graph 0.0625450611114502
# _find_lowest_cost_edges 0.0062601566314697266
# --------- step:  82 ---------
# _merge_nodes 0.015752792358398438
# _update_merge_graph 0.0500028133392334
# _find_lowest_cost_edges 0.006133079528808594
# --------- step:  83 ---------
# _merge_nodes 0.014712095260620117
# _update_merge_graph 0.049320220947265625
# _find_lowest_cost_edges 0.006762504577636719
# --------- step:  84 ---------
# _merge_nodes 0.012453794479370117
# _update_merge_graph 0.04765629768371582
# _find_lowest_cost_edges 0.0072972774505615234
# --------- step:  85 ---------
# _merge_nodes 0.012842178344726562
# _update_merge_graph 0.04885673522949219
# _find_lowest_cost_edges 0.007210493087768555
# --------- step:  86 ---------
# _merge_nodes 0.01304936408996582
# _update_merge_graph 0.054761648178100586
# _find_lowest_cost_edges 0.005509138107299805
# --------- step:  87 ---------
# _merge_nodes 0.01676201820373535
# _update_merge_graph 0.05078554153442383
# _find_lowest_cost_edges 0.007246494293212891
# --------- step:  88 ---------
# _merge_nodes 0.014030694961547852
# _update_merge_graph 0.0487518310546875
# _find_lowest_cost_edges 0.006289005279541016
# --------- step:  89 ---------
# _merge_nodes 0.021950721740722656
# _update_merge_graph 0.05840134620666504
# _find_lowest_cost_edges 0.006040096282958984
# --------- step:  90 ---------
# _merge_nodes 0.022842884063720703
# _update_merge_graph 0.06616330146789551
# _find_lowest_cost_edges 0.006208896636962891
# --------- step:  91 ---------
# _merge_nodes 0.017008304595947266
# _update_merge_graph 0.05285024642944336
# _find_lowest_cost_edges 0.0069086551666259766
# --------- step:  92 ---------
# _merge_nodes 0.017324209213256836
# _update_merge_graph 0.0592494010925293
# _find_lowest_cost_edges 0.004446744918823242
# --------- step:  93 ---------
# _merge_nodes 0.027731895446777344
# _update_merge_graph 0.07166767120361328
# _find_lowest_cost_edges 0.005252838134765625
# --------- step:  94 ---------
# _merge_nodes 0.032776832580566406
# _update_merge_graph 0.057878732681274414
# _find_lowest_cost_edges 0.005886077880859375
# --------- step:  95 ---------
# _merge_nodes 0.01789999008178711
# _update_merge_graph 0.05571913719177246
# _find_lowest_cost_edges 0.007293224334716797
# --------- step:  96 ---------
# _merge_nodes 0.014706850051879883
# _update_merge_graph 0.053380489349365234
# _find_lowest_cost_edges 0.006402492523193359
# --------- step:  97 ---------
# _merge_nodes 0.02353525161743164
# _update_merge_graph 0.060832977294921875
# _find_lowest_cost_edges 0.0060176849365234375
# --------- step:  98 ---------
# _merge_nodes 0.02057361602783203
# _update_merge_graph 0.0712442398071289
# _find_lowest_cost_edges 0.005356788635253906
# --------- step:  99 ---------
# _merge_nodes 0.01937723159790039
# _update_merge_graph 0.05037355422973633
# _find_lowest_cost_edges 0.007358551025390625
# --------- step:  100 ---------
# _merge_nodes 0.01889944076538086
# _update_merge_graph 0.060596466064453125
# _find_lowest_cost_edges 0.005468130111694336
# --------- step:  101 ---------
# _merge_nodes 0.025317668914794922
# _update_merge_graph 0.07427859306335449
# _find_lowest_cost_edges 0.007205486297607422
# --------- step:  102 ---------
# _merge_nodes 0.01813673973083496
# _update_merge_graph 0.05804133415222168
# _find_lowest_cost_edges 0.005802631378173828
# --------- step:  103 ---------
# _merge_nodes 0.028497695922851562
# _update_merge_graph 0.05788397789001465
# _find_lowest_cost_edges 0.007188081741333008
# --------- step:  104 ---------
# _merge_nodes 0.0179750919342041
# _update_merge_graph 0.05493640899658203
# _find_lowest_cost_edges 0.005564451217651367
# --------- step:  105 ---------
# _merge_nodes 0.01824355125427246
# _update_merge_graph 0.05644631385803223
# _find_lowest_cost_edges 0.006376504898071289
# --------- step:  106 ---------
# _merge_nodes 0.014901161193847656
# _update_merge_graph 0.06344008445739746
# _find_lowest_cost_edges 0.0060846805572509766
# --------- step:  107 ---------
# _merge_nodes 0.021462202072143555
# _update_merge_graph 0.0626230239868164
# _find_lowest_cost_edges 0.00608515739440918
# --------- step:  108 ---------
# _merge_nodes 0.022556543350219727
# _update_merge_graph 0.07404375076293945
# _find_lowest_cost_edges 0.005161285400390625
# --------- step:  109 ---------
# _merge_nodes 0.02652740478515625
# _update_merge_graph 0.06081795692443848
# _find_lowest_cost_edges 0.007512092590332031
# --------- step:  110 ---------
# _merge_nodes 0.019071340560913086
# _update_merge_graph 0.061203718185424805
# _find_lowest_cost_edges 0.007343292236328125
# --------- step:  111 ---------
# _merge_nodes 0.031171798706054688
# _update_merge_graph 0.05248427391052246
# _find_lowest_cost_edges 0.007474422454833984
# --------- step:  112 ---------
# _merge_nodes 0.012566566467285156
# _update_merge_graph 0.04944133758544922
# _find_lowest_cost_edges 0.006619453430175781
# --------- step:  113 ---------
# _merge_nodes 0.02188706398010254
# _update_merge_graph 0.0969388484954834
# _find_lowest_cost_edges 0.006096601486206055
# --------- step:  114 ---------
# _merge_nodes 0.043766021728515625
# _update_merge_graph 0.07787275314331055
# _find_lowest_cost_edges 0.007737874984741211
# --------- step:  115 ---------
# _merge_nodes 0.018720626831054688
# _update_merge_graph 0.05121946334838867
# _find_lowest_cost_edges 0.008045673370361328
# --------- step:  116 ---------
# _merge_nodes 0.01420450210571289
# _update_merge_graph 0.06543993949890137
# _find_lowest_cost_edges 0.003981828689575195
# --------- step:  117 ---------
# _merge_nodes 0.020033597946166992
# _update_merge_graph 0.05175638198852539
# _find_lowest_cost_edges 0.007208347320556641
# --------- step:  118 ---------
# _merge_nodes 0.013808727264404297
# _update_merge_graph 0.05205130577087402
# _find_lowest_cost_edges 0.004510641098022461
# --------- step:  119 ---------
# _merge_nodes 0.016202211380004883
# _update_merge_graph 0.057392120361328125
# _find_lowest_cost_edges 0.007919549942016602
# --------- step:  120 ---------
# _merge_nodes 0.012954950332641602
# _update_merge_graph 0.06371903419494629
# _find_lowest_cost_edges 0.0038213729858398438
# --------- step:  121 ---------
# _merge_nodes 0.022421836853027344
# _update_merge_graph 0.053203582763671875
# _find_lowest_cost_edges 0.007117271423339844
# --------- step:  122 ---------
# _merge_nodes 0.025497913360595703
# _update_merge_graph 0.08465886116027832
# _find_lowest_cost_edges 0.004954338073730469
# --------- step:  123 ---------
# _merge_nodes 0.03625679016113281
# _update_merge_graph 0.07814812660217285
# _find_lowest_cost_edges 0.004842996597290039
# --------- step:  124 ---------
# _merge_nodes 0.031934499740600586
# _update_merge_graph 0.06442475318908691
# _find_lowest_cost_edges 0.005742788314819336
# --------- step:  125 ---------
# _merge_nodes 0.023240327835083008
# _update_merge_graph 0.05541110038757324
# _find_lowest_cost_edges 0.007203102111816406
# --------- step:  126 ---------
# _merge_nodes 0.016648530960083008
# _update_merge_graph 0.06068563461303711
# _find_lowest_cost_edges 0.0050432682037353516
# --------- step:  127 ---------
# _merge_nodes 0.021905899047851562
# _update_merge_graph 0.0649421215057373
# _find_lowest_cost_edges 0.005219459533691406
# --------- step:  128 ---------
# _merge_nodes 0.020453929901123047
# _update_merge_graph 0.060654640197753906
# _find_lowest_cost_edges 0.004177093505859375
# --------- step:  129 ---------
# _merge_nodes 0.025598526000976562
# _update_merge_graph 0.05727791786193848
# _find_lowest_cost_edges 0.006257057189941406
# --------- step:  130 ---------
# _merge_nodes 0.017339229583740234
# _update_merge_graph 0.05922365188598633
# _find_lowest_cost_edges 0.006942033767700195
# --------- step:  131 ---------
# _merge_nodes 0.02310657501220703
# _update_merge_graph 0.056002140045166016
# _find_lowest_cost_edges 0.006044626235961914
# --------- step:  132 ---------
# _merge_nodes 0.021301984786987305
# _update_merge_graph 0.06696581840515137
# _find_lowest_cost_edges 0.006338834762573242
# --------- step:  133 ---------
# _merge_nodes 0.022710561752319336
# _update_merge_graph 0.0592045783996582
# _find_lowest_cost_edges 0.0068206787109375
# --------- step:  134 ---------
# _merge_nodes 0.015581607818603516
# _update_merge_graph 0.05740690231323242
# _find_lowest_cost_edges 0.006952047348022461
# --------- step:  135 ---------
# _merge_nodes 0.02228379249572754
# _update_merge_graph 0.07226800918579102
# _find_lowest_cost_edges 0.005086183547973633
# --------- step:  136 ---------
# _merge_nodes 0.02685713768005371
# _update_merge_graph 0.06717348098754883
# _find_lowest_cost_edges 0.006909608840942383
# --------- step:  137 ---------
# _merge_nodes 0.02118539810180664
# _update_merge_graph 0.0652458667755127
# _find_lowest_cost_edges 0.0067996978759765625
# --------- step:  138 ---------
# _merge_nodes 0.021211624145507812
# _update_merge_graph 0.06234550476074219
# _find_lowest_cost_edges 0.007092952728271484
# --------- step:  139 ---------
# _merge_nodes 0.029573917388916016
# _update_merge_graph 0.07171130180358887
# _find_lowest_cost_edges 0.0063364505767822266
# --------- step:  140 ---------
# _merge_nodes 0.027165651321411133
# _update_merge_graph 0.07060623168945312
# _find_lowest_cost_edges 0.007221221923828125
# --------- step:  141 ---------
# _merge_nodes 0.02460455894470215
# _update_merge_graph 0.08065462112426758
# _find_lowest_cost_edges 0.007077932357788086
# --------- step:  142 ---------
# _merge_nodes 0.025989770889282227
# _update_merge_graph 0.06216883659362793
# _find_lowest_cost_edges 0.008573055267333984
# --------- step:  143 ---------
# _merge_nodes 0.01680135726928711
# _update_merge_graph 0.0654597282409668
# _find_lowest_cost_edges 0.00673985481262207
# --------- step:  144 ---------
# _merge_nodes 0.01717352867126465
# _update_merge_graph 0.07152175903320312
# _find_lowest_cost_edges 0.005220651626586914
# --------- step:  145 ---------
# _merge_nodes 0.01483464241027832
# _update_merge_graph 0.059374332427978516
# _find_lowest_cost_edges 0.00829005241394043
# --------- step:  146 ---------
# _merge_nodes 0.01334691047668457
# _update_merge_graph 0.061971426010131836
# _find_lowest_cost_edges 0.007521867752075195
# --------- step:  147 ---------
# _merge_nodes 0.016593456268310547
# _update_merge_graph 0.05549955368041992
# _find_lowest_cost_edges 0.007999658584594727
# --------- step:  148 ---------
# _merge_nodes 0.017457246780395508
# _update_merge_graph 0.07716989517211914
# _find_lowest_cost_edges 0.007052183151245117
# --------- step:  149 ---------
# _merge_nodes 0.02272486686706543
# _update_merge_graph 0.07987523078918457
# _find_lowest_cost_edges 0.004608869552612305
# --------- step:  150 ---------
# _merge_nodes 0.025758981704711914
# _update_merge_graph 0.061261653900146484
# _find_lowest_cost_edges 0.00667119026184082
# --------- step:  151 ---------
# _merge_nodes 0.018166780471801758
# _update_merge_graph 0.05752396583557129
# _find_lowest_cost_edges 0.003141641616821289
# --------- step:  152 ---------
# _merge_nodes 0.027248144149780273
# _update_merge_graph 0.04969596862792969
# _find_lowest_cost_edges 0.007745981216430664
# --------- step:  153 ---------
# _merge_nodes 0.01494145393371582
# _update_merge_graph 0.050931453704833984
# _find_lowest_cost_edges 0.006917715072631836
# --------- step:  154 ---------
# _merge_nodes 0.023121118545532227
# _update_merge_graph 0.06220722198486328
# _find_lowest_cost_edges 0.0059206485748291016
# --------- step:  155 ---------
# _merge_nodes 0.06791925430297852
# _update_merge_graph 0.10395169258117676
# _find_lowest_cost_edges 0.00287628173828125
# --------- step:  156 ---------
# _merge_nodes 0.05689287185668945
# _update_merge_graph 0.052938222885131836
# _find_lowest_cost_edges 0.00721430778503418
# --------- step:  157 ---------
# _merge_nodes 0.012687206268310547
# _update_merge_graph 0.05240678787231445
# _find_lowest_cost_edges 0.00690150260925293
# --------- step:  158 ---------
# _merge_nodes 0.024277925491333008
# _update_merge_graph 0.07919979095458984
# _find_lowest_cost_edges 0.004063606262207031
# --------- step:  159 ---------
# _merge_nodes 0.014514684677124023
# _update_merge_graph 0.053865909576416016
# _find_lowest_cost_edges 0.006354093551635742
# --------- step:  160 ---------
# _merge_nodes 0.018151521682739258
# _update_merge_graph 0.049361228942871094
# _find_lowest_cost_edges 0.006571769714355469
# --------- step:  161 ---------
# _merge_nodes 0.02183246612548828
# _update_merge_graph 0.04916787147521973
# _find_lowest_cost_edges 0.006652116775512695
# --------- step:  162 ---------
# _merge_nodes 0.021670818328857422
# _update_merge_graph 0.06450319290161133
# _find_lowest_cost_edges 0.0068132877349853516
# --------- step:  163 ---------
# _merge_nodes 0.022086620330810547
# _update_merge_graph 0.0772554874420166
# _find_lowest_cost_edges 0.0063343048095703125
# --------- step:  164 ---------
# _merge_nodes 0.02188730239868164
# _update_merge_graph 0.12179422378540039
# _find_lowest_cost_edges 0.0025436878204345703
# --------- step:  165 ---------
# _merge_nodes 0.03313040733337402
# _update_merge_graph 0.06404709815979004
# _find_lowest_cost_edges 0.0075283050537109375
# --------- step:  166 ---------
# _merge_nodes 0.01925516128540039
# _update_merge_graph 0.06351733207702637
# _find_lowest_cost_edges 0.006838560104370117
# --------- step:  167 ---------
# _merge_nodes 0.01970672607421875
# _update_merge_graph 0.06522941589355469
# _find_lowest_cost_edges 0.00791621208190918
# --------- step:  168 ---------
# _merge_nodes 0.01654672622680664
# _update_merge_graph 0.05675458908081055
# _find_lowest_cost_edges 0.007201433181762695
# --------- step:  169 ---------
# _merge_nodes 0.01435542106628418
# _update_merge_graph 0.053534507751464844
# _find_lowest_cost_edges 0.007780790328979492
# --------- step:  170 ---------
# _merge_nodes 0.01565098762512207
# _update_merge_graph 0.06020021438598633
# _find_lowest_cost_edges 0.003926277160644531
# --------- step:  171 ---------
# _merge_nodes 0.01919102668762207
# _update_merge_graph 0.06092262268066406
# _find_lowest_cost_edges 0.007429599761962891
# --------- step:  172 ---------
# _merge_nodes 0.0339505672454834
# _update_merge_graph 0.05943107604980469
# _find_lowest_cost_edges 0.0076045989990234375
# --------- step:  173 ---------
# _merge_nodes 0.0286407470703125
# _update_merge_graph 0.07078003883361816
# _find_lowest_cost_edges 0.005196094512939453
# --------- step:  174 ---------
# _merge_nodes 0.013826608657836914
# _update_merge_graph 0.05263233184814453
# _find_lowest_cost_edges 0.006508827209472656
# --------- step:  175 ---------
# _merge_nodes 0.017337322235107422
# _update_merge_graph 0.05346560478210449
# _find_lowest_cost_edges 0.008465290069580078
# --------- step:  176 ---------
# _merge_nodes 0.015543699264526367
# _update_merge_graph 0.04957938194274902
# _find_lowest_cost_edges 0.007523298263549805
# --------- step:  177 ---------
# _merge_nodes 0.022510290145874023
# _update_merge_graph 0.05424165725708008
# _find_lowest_cost_edges 0.006978511810302734
# --------- step:  178 ---------
# _merge_nodes 0.01847982406616211
# _update_merge_graph 0.06458306312561035
# _find_lowest_cost_edges 0.005823612213134766
# --------- step:  179 ---------
# _merge_nodes 0.018166780471801758
# _update_merge_graph 0.06833839416503906
# _find_lowest_cost_edges 0.0040798187255859375
# --------- step:  180 ---------
# _merge_nodes 0.022904157638549805
# _update_merge_graph 0.06881284713745117
# _find_lowest_cost_edges 0.005150318145751953
# --------- step:  181 ---------
# _merge_nodes 0.019726276397705078
# _update_merge_graph 0.05576157569885254
# _find_lowest_cost_edges 0.005232095718383789
# --------- step:  182 ---------
# _merge_nodes 0.023627758026123047
# _update_merge_graph 0.049794912338256836
# _find_lowest_cost_edges 0.0070116519927978516
# --------- step:  183 ---------
# _merge_nodes 0.01865553855895996
# _update_merge_graph 0.05515575408935547
# _find_lowest_cost_edges 0.006661891937255859
# --------- step:  184 ---------
# _merge_nodes 0.018083572387695312
# _update_merge_graph 0.055774688720703125
# _find_lowest_cost_edges 0.006489992141723633
# --------- step:  185 ---------
# _merge_nodes 0.029856204986572266
# _update_merge_graph 0.05999279022216797
# _find_lowest_cost_edges 0.004988908767700195
# --------- step:  186 ---------
# _merge_nodes 0.024042367935180664
# _update_merge_graph 0.06535506248474121
# _find_lowest_cost_edges 0.004607439041137695
# --------- step:  187 ---------
# _merge_nodes 0.04160022735595703
# _update_merge_graph 0.07788538932800293
# _find_lowest_cost_edges 0.004341840744018555
# --------- step:  188 ---------
# _merge_nodes 0.03516411781311035
# _update_merge_graph 0.06037592887878418
# _find_lowest_cost_edges 0.00582122802734375
# --------- step:  189 ---------
# _merge_nodes 0.03490924835205078
# _update_merge_graph 0.05075812339782715
# _find_lowest_cost_edges 0.006078243255615234
# --------- step:  190 ---------
# _merge_nodes 0.017624616622924805
# _update_merge_graph 0.0822148323059082
# _find_lowest_cost_edges 0.003921985626220703
# --------- step:  191 ---------
# _merge_nodes 0.03150796890258789
# _update_merge_graph 0.09381270408630371
# _find_lowest_cost_edges 0.003960371017456055
# --------- step:  192 ---------
# _merge_nodes 0.040790557861328125
# _update_merge_graph 0.06413626670837402
# _find_lowest_cost_edges 0.006269693374633789
# --------- step:  193 ---------
# _merge_nodes 0.01423192024230957
# _update_merge_graph 0.05455160140991211
# _find_lowest_cost_edges 0.0085601806640625
# --------- step:  194 ---------
# _merge_nodes 0.01548457145690918
# _update_merge_graph 0.05474686622619629
# _find_lowest_cost_edges 0.008107662200927734
# --------- step:  195 ---------
# _merge_nodes 0.024452924728393555
# _update_merge_graph 0.07690238952636719
# _find_lowest_cost_edges 0.0064868927001953125
# --------- step:  196 ---------
# _merge_nodes 0.019474506378173828
# _update_merge_graph 0.06764602661132812
# _find_lowest_cost_edges 0.007264137268066406
# --------- step:  197 ---------
# _merge_nodes 0.017951011657714844
# _update_merge_graph 0.05512857437133789
# _find_lowest_cost_edges 0.007651090621948242
# --------- step:  198 ---------
# _merge_nodes 0.014783620834350586
# _update_merge_graph 0.0596163272857666
# _find_lowest_cost_edges 0.006944894790649414
# --------- step:  199 ---------
# _merge_nodes 0.03444933891296387
# _update_merge_graph 0.0644071102142334
# _find_lowest_cost_edges 0.0064427852630615234
# --------- step:  200 ---------
# _merge_nodes 0.02147841453552246
# _update_merge_graph 0.05298638343811035
# _find_lowest_cost_edges 0.008005142211914062
# --------- step:  201 ---------
# _merge_nodes 0.012709856033325195
# _update_merge_graph 0.048154592514038086
# _find_lowest_cost_edges 0.0074062347412109375
# --------- step:  202 ---------
# _merge_nodes 0.01303553581237793
# _update_merge_graph 0.049162864685058594
# _find_lowest_cost_edges 0.0073986053466796875
# --------- step:  203 ---------
# _merge_nodes 0.012960672378540039
# _update_merge_graph 0.05314326286315918
# _find_lowest_cost_edges 0.006739616394042969
# --------- step:  204 ---------
# _merge_nodes 0.015948772430419922
# _update_merge_graph 0.05087161064147949
# _find_lowest_cost_edges 0.0055522918701171875
# --------- step:  205 ---------
# _merge_nodes 0.030384302139282227
# _update_merge_graph 0.056276798248291016
# _find_lowest_cost_edges 0.00572514533996582
# --------- step:  206 ---------
# _merge_nodes 0.016259431838989258
# _update_merge_graph 0.04514336585998535
# _find_lowest_cost_edges 0.0058252811431884766
# --------- step:  207 ---------
# _merge_nodes 0.011683940887451172
# _update_merge_graph 0.06314873695373535
# _find_lowest_cost_edges 0.004148960113525391
# --------- step:  208 ---------
# _merge_nodes 0.030408143997192383
# _update_merge_graph 0.06733441352844238
# _find_lowest_cost_edges 0.005402565002441406
# --------- step:  209 ---------
# _merge_nodes 0.021045207977294922
# _update_merge_graph 0.04246211051940918
# _find_lowest_cost_edges 0.00603175163269043
# --------- step:  210 ---------
# _merge_nodes 0.01342153549194336
# _update_merge_graph 0.04368758201599121
# _find_lowest_cost_edges 0.005214691162109375
# --------- step:  211 ---------
# _merge_nodes 0.012157678604125977
# _update_merge_graph 0.050328969955444336
# _find_lowest_cost_edges 0.005817890167236328
# --------- step:  212 ---------
# _merge_nodes 0.013821125030517578
# _update_merge_graph 0.04752826690673828
# _find_lowest_cost_edges 0.006004810333251953
# --------- step:  213 ---------
# _merge_nodes 0.019192934036254883
# _update_merge_graph 0.06165361404418945
# _find_lowest_cost_edges 0.004518747329711914
# --------- step:  214 ---------
# _merge_nodes 0.021250009536743164
# _update_merge_graph 0.049652099609375
# _find_lowest_cost_edges 0.005403757095336914
# --------- step:  215 ---------
# _merge_nodes 0.01876664161682129
# _update_merge_graph 0.06961536407470703
# _find_lowest_cost_edges 0.0035963058471679688
# --------- step:  216 ---------
# _merge_nodes 0.020702362060546875
# _update_merge_graph 0.05716753005981445
# _find_lowest_cost_edges 0.005892515182495117
# --------- step:  217 ---------
# _merge_nodes 0.015596389770507812
# _update_merge_graph 0.05230093002319336
# _find_lowest_cost_edges 0.004563808441162109
# --------- step:  218 ---------
# _merge_nodes 0.01970982551574707
# _update_merge_graph 0.04992556571960449
# _find_lowest_cost_edges 0.0052835941314697266
# --------- step:  219 ---------
# _merge_nodes 0.021805524826049805
# _update_merge_graph 0.06427931785583496
# _find_lowest_cost_edges 0.0034193992614746094
# --------- step:  220 ---------
# _merge_nodes 0.028346776962280273
# _update_merge_graph 0.04696011543273926
# _find_lowest_cost_edges 0.0071980953216552734
# --------- step:  221 ---------
# _merge_nodes 0.011722564697265625
# _update_merge_graph 0.044878244400024414
# _find_lowest_cost_edges 0.0062029361724853516
# --------- step:  222 ---------
# _merge_nodes 0.013650655746459961
# _update_merge_graph 0.05074000358581543
# _find_lowest_cost_edges 0.005721092224121094
# --------- step:  223 ---------
# _merge_nodes 0.01819157600402832
# _update_merge_graph 0.058612823486328125
# _find_lowest_cost_edges 0.004918575286865234
# --------- step:  224 ---------
# _merge_nodes 0.02583146095275879
# _update_merge_graph 0.07276582717895508
# _find_lowest_cost_edges 0.0012989044189453125
# --------- step:  225 ---------
# _merge_nodes 0.023703575134277344
# _update_merge_graph 0.08351278305053711
# _find_lowest_cost_edges 0.0038938522338867188
# --------- step:  226 ---------
# _merge_nodes 0.026837825775146484
# _update_merge_graph 0.04807233810424805
# _find_lowest_cost_edges 0.00479888916015625
# --------- step:  227 ---------
# _merge_nodes 0.01723456382751465
# _update_merge_graph 0.04562735557556152
# _find_lowest_cost_edges 0.005072116851806641
# --------- step:  228 ---------
# _merge_nodes 0.01466226577758789
# _update_merge_graph 0.06160902976989746
# _find_lowest_cost_edges 0.004002809524536133
# --------- step:  229 ---------
# _merge_nodes 0.01572132110595703
# _update_merge_graph 0.04715251922607422
# _find_lowest_cost_edges 0.00543212890625
# --------- step:  230 ---------
# _merge_nodes 0.012345075607299805
# _update_merge_graph 0.04860734939575195
# _find_lowest_cost_edges 0.004919528961181641
# --------- step:  231 ---------
# _merge_nodes 0.016695499420166016
# _update_merge_graph 0.051637887954711914
# _find_lowest_cost_edges 0.004302501678466797
# --------- step:  232 ---------
# _merge_nodes 0.01682591438293457
# _update_merge_graph 0.05189085006713867
# _find_lowest_cost_edges 0.004494428634643555
# --------- step:  233 ---------
# _merge_nodes 0.013507366180419922
# _update_merge_graph 0.04277539253234863
# _find_lowest_cost_edges 0.0052700042724609375
# --------- step:  234 ---------
# _merge_nodes 0.012423038482666016
# _update_merge_graph 0.04194951057434082
# _find_lowest_cost_edges 0.005393266677856445
# --------- step:  235 ---------
# _merge_nodes 0.012694597244262695
# _update_merge_graph 0.048390865325927734
# _find_lowest_cost_edges 0.004019975662231445
# --------- step:  236 ---------
# _merge_nodes 0.011925935745239258
# _update_merge_graph 0.03991079330444336
# _find_lowest_cost_edges 0.005559682846069336
# --------- step:  237 ---------
# _merge_nodes 0.011704444885253906
# _update_merge_graph 0.04007554054260254
# _find_lowest_cost_edges 0.005866289138793945
# --------- step:  238 ---------
# _merge_nodes 0.02450728416442871
# _update_merge_graph 0.0430145263671875
# _find_lowest_cost_edges 0.004395961761474609
# --------- step:  239 ---------
# _merge_nodes 0.011507749557495117
# _update_merge_graph 0.04417777061462402
# _find_lowest_cost_edges 0.004094362258911133
# --------- step:  240 ---------
# _merge_nodes 0.01711583137512207
# _update_merge_graph 0.05189871788024902
# _find_lowest_cost_edges 0.0044252872467041016
# --------- step:  241 ---------
# _merge_nodes 0.02080082893371582
# _update_merge_graph 0.04665684700012207
# _find_lowest_cost_edges 0.0055828094482421875
# --------- step:  242 ---------
# _merge_nodes 0.011529207229614258
# _update_merge_graph 0.0462946891784668
# _find_lowest_cost_edges 0.005327463150024414
# --------- step:  243 ---------
# _merge_nodes 0.0221405029296875
# _update_merge_graph 0.047026872634887695
# _find_lowest_cost_edges 0.0050678253173828125
# --------- step:  244 ---------
# _merge_nodes 0.029791831970214844
# _update_merge_graph 0.06197667121887207
# _find_lowest_cost_edges 0.003606557846069336
# --------- step:  245 ---------
# _merge_nodes 0.032219886779785156
# _update_merge_graph 0.04374194145202637
# _find_lowest_cost_edges 0.004934549331665039
# --------- step:  246 ---------
# _merge_nodes 0.015008687973022461
# _update_merge_graph 0.04381847381591797
# _find_lowest_cost_edges 0.005942344665527344
# --------- step:  247 ---------
# _merge_nodes 0.024111032485961914
# _update_merge_graph 0.06587815284729004
# _find_lowest_cost_edges 0.002399921417236328
# --------- step:  248 ---------
# _merge_nodes 0.024823904037475586
# _update_merge_graph 0.06955265998840332
# _find_lowest_cost_edges 0.005505800247192383
# --------- step:  249 ---------
# _merge_nodes 0.031270742416381836
# _update_merge_graph 0.07743620872497559
# _find_lowest_cost_edges 0.0023446083068847656
# --------- step:  250 ---------
# _merge_nodes 0.029431581497192383
# _update_merge_graph 0.08336997032165527
# _find_lowest_cost_edges 0.00403141975402832
# --------- step:  251 ---------
# _merge_nodes 0.029125213623046875
# _update_merge_graph 0.07070755958557129
# _find_lowest_cost_edges 0.004243612289428711
# --------- step:  252 ---------
# _merge_nodes 0.038663625717163086
# _update_merge_graph 0.07324361801147461
# _find_lowest_cost_edges 0.006823062896728516
# --------- step:  253 ---------
# _merge_nodes 0.02112603187561035
# _update_merge_graph 0.0688161849975586
# _find_lowest_cost_edges 0.005177974700927734
# --------- step:  254 ---------
# _merge_nodes 0.021535158157348633
# _update_merge_graph 0.06374859809875488
# _find_lowest_cost_edges 0.003314971923828125
# --------- step:  255 ---------
# _merge_nodes 0.021497488021850586
# _update_merge_graph 0.04956221580505371
# _find_lowest_cost_edges 0.006083965301513672
# --------- step:  256 ---------
# _merge_nodes 0.015611648559570312
# _update_merge_graph 0.05815291404724121
# _find_lowest_cost_edges 0.0043981075286865234
# --------- step:  257 ---------
# _merge_nodes 0.014483928680419922
# _update_merge_graph 0.043485164642333984
# _find_lowest_cost_edges 0.006997585296630859
# --------- step:  258 ---------
# _merge_nodes 0.011368989944458008
# _update_merge_graph 0.04641532897949219
# _find_lowest_cost_edges 0.006412982940673828
# --------- step:  259 ---------
# _merge_nodes 0.023563385009765625
# _update_merge_graph 0.0553128719329834
# _find_lowest_cost_edges 0.006622314453125
# --------- step:  260 ---------
# _merge_nodes 0.01299428939819336
# _update_merge_graph 0.04633355140686035
# _find_lowest_cost_edges 0.006711244583129883
# --------- step:  261 ---------
# _merge_nodes 0.020728349685668945
# _update_merge_graph 0.04868721961975098
# _find_lowest_cost_edges 0.00688624382019043
# --------- step:  262 ---------
# _merge_nodes 0.012535572052001953
# _update_merge_graph 0.044677019119262695
# _find_lowest_cost_edges 0.006461381912231445
# --------- step:  263 ---------
# _merge_nodes 0.012361764907836914
# _update_merge_graph 0.04680967330932617
# _find_lowest_cost_edges 0.0050508975982666016
# --------- step:  264 ---------
# _merge_nodes 0.03427886962890625
# _update_merge_graph 0.04551291465759277
# _find_lowest_cost_edges 0.004461765289306641
# --------- step:  265 ---------
# _merge_nodes 0.030203819274902344
# _update_merge_graph 0.044457197189331055
# _find_lowest_cost_edges 0.004678487777709961
# --------- step:  266 ---------
# _merge_nodes 0.015225410461425781
# _update_merge_graph 0.042546749114990234
# _find_lowest_cost_edges 0.005699634552001953
# --------- step:  267 ---------
# _merge_nodes 0.013583660125732422
# _update_merge_graph 0.04163670539855957
# _find_lowest_cost_edges 0.0055217742919921875
# --------- step:  268 ---------
# _merge_nodes 0.012351512908935547
# _update_merge_graph 0.04152631759643555
# _find_lowest_cost_edges 0.004235982894897461
# --------- step:  269 ---------
# _merge_nodes 0.012571096420288086
# _update_merge_graph 0.04899334907531738
# _find_lowest_cost_edges 0.00459599494934082
# --------- step:  270 ---------
# _merge_nodes 0.0324101448059082
# _update_merge_graph 0.05117464065551758
# _find_lowest_cost_edges 0.0032455921173095703
# --------- step:  271 ---------
# _merge_nodes 0.02023482322692871
# _update_merge_graph 0.04269695281982422
# _find_lowest_cost_edges 0.004709005355834961
# --------- step:  272 ---------
# _merge_nodes 0.012745141983032227
# _update_merge_graph 0.044992685317993164
# _find_lowest_cost_edges 0.0038514137268066406
# --------- step:  273 ---------
# _merge_nodes 0.017195463180541992
# _update_merge_graph 0.041197776794433594
# _find_lowest_cost_edges 0.004788398742675781
# --------- step:  274 ---------
# _merge_nodes 0.010828018188476562
# _update_merge_graph 0.06348109245300293
# _find_lowest_cost_edges 0.002911806106567383
# --------- step:  275 ---------
# _merge_nodes 0.024021387100219727
# _update_merge_graph 0.04503202438354492
# _find_lowest_cost_edges 0.004115581512451172
# --------- step:  276 ---------
# _merge_nodes 0.013503074645996094
# _update_merge_graph 0.037123680114746094
# _find_lowest_cost_edges 0.004937171936035156
# --------- step:  277 ---------
# _merge_nodes 0.01159811019897461
# _update_merge_graph 0.038316965103149414
# _find_lowest_cost_edges 0.004933357238769531
# --------- step:  278 ---------
# _merge_nodes 0.022613525390625
# _update_merge_graph 0.0572507381439209
# _find_lowest_cost_edges 0.0020847320556640625
# --------- step:  279 ---------
# _merge_nodes 0.04712843894958496
# _update_merge_graph 0.0775136947631836
# _find_lowest_cost_edges 0.0026683807373046875
# --------- step:  280 ---------
# _merge_nodes 0.0348973274230957
# _update_merge_graph 0.06520652770996094
# _find_lowest_cost_edges 0.002353668212890625
# --------- step:  281 ---------
# _merge_nodes 0.02931499481201172
# _update_merge_graph 0.06838822364807129
# _find_lowest_cost_edges 0.003623485565185547
# --------- step:  282 ---------
# _merge_nodes 0.032822608947753906
# _update_merge_graph 0.06818866729736328
# _find_lowest_cost_edges 0.002825021743774414
# --------- step:  283 ---------
# _merge_nodes 0.027329444885253906
# _update_merge_graph 0.06107521057128906
# _find_lowest_cost_edges 0.0017788410186767578
# --------- step:  284 ---------
# _merge_nodes 0.02548360824584961
# _update_merge_graph 0.06656575202941895
# _find_lowest_cost_edges 0.004120588302612305
# --------- step:  285 ---------
# _merge_nodes 0.03673696517944336
# _update_merge_graph 0.08363580703735352
# _find_lowest_cost_edges 0.00266265869140625
# --------- step:  286 ---------
# _merge_nodes 0.03393673896789551
# _update_merge_graph 0.07876181602478027
# _find_lowest_cost_edges 0.005330801010131836
# --------- step:  287 ---------
# _merge_nodes 0.03292107582092285
# _update_merge_graph 0.07917404174804688
# _find_lowest_cost_edges 0.0062313079833984375
# --------- step:  288 ---------
# _merge_nodes 0.03818392753601074
# _update_merge_graph 0.07889556884765625
# _find_lowest_cost_edges 0.002513408660888672
# --------- step:  289 ---------
# _merge_nodes 0.026816606521606445
# _update_merge_graph 0.0656893253326416
# _find_lowest_cost_edges 0.004273653030395508
# --------- step:  290 ---------
# _merge_nodes 0.0434877872467041
# _update_merge_graph 0.08107686042785645
# _find_lowest_cost_edges 0.006371021270751953
# --------- step:  291 ---------
# _merge_nodes 0.01824665069580078
# _update_merge_graph 0.07954883575439453
# _find_lowest_cost_edges 0.003875732421875
# --------- step:  292 ---------
# _merge_nodes 0.026411771774291992
# _update_merge_graph 0.059101104736328125
# _find_lowest_cost_edges 0.0068340301513671875
# --------- step:  293 ---------
# _merge_nodes 0.015456914901733398
# _update_merge_graph 0.04513382911682129
# _find_lowest_cost_edges 0.006988525390625
# --------- step:  294 ---------
# _merge_nodes 0.013667583465576172
# _update_merge_graph 0.04442191123962402
# _find_lowest_cost_edges 0.007882118225097656
# --------- step:  295 ---------
# _merge_nodes 0.01153111457824707
# _update_merge_graph 0.04286026954650879
# _find_lowest_cost_edges 0.006483316421508789
# --------- step:  296 ---------
# _merge_nodes 0.011518001556396484
# _update_merge_graph 0.044318437576293945
# _find_lowest_cost_edges 0.005886554718017578
# --------- step:  297 ---------
# _merge_nodes 0.011851310729980469
# _update_merge_graph 0.04273557662963867
# _find_lowest_cost_edges 0.005722999572753906
# --------- step:  298 ---------
# _merge_nodes 0.012664556503295898
# _update_merge_graph 0.039681196212768555
# _find_lowest_cost_edges 0.0058591365814208984
# --------- step:  299 ---------
# _merge_nodes 0.01307821273803711
# _update_merge_graph 0.04351520538330078
# _find_lowest_cost_edges 0.0054531097412109375
# --------- step:  300 ---------
# _merge_nodes 0.01209712028503418
# _update_merge_graph 0.03919839859008789
# _find_lowest_cost_edges 0.005794048309326172
# --------- step:  301 ---------
# _merge_nodes 0.012629508972167969
# _update_merge_graph 0.04514455795288086
# _find_lowest_cost_edges 0.005255699157714844
# --------- step:  302 ---------
# _merge_nodes 0.01912999153137207
# _update_merge_graph 0.06844735145568848
# _find_lowest_cost_edges 0.004532575607299805
# --------- step:  303 ---------
# _merge_nodes 0.047979116439819336
# _update_merge_graph 0.0756070613861084
# _find_lowest_cost_edges 0.002404928207397461
# --------- step:  304 ---------
# _merge_nodes 0.03213191032409668
# _update_merge_graph 0.07639408111572266
# _find_lowest_cost_edges 0.002283334732055664
# --------- step:  305 ---------
# _merge_nodes 0.029814720153808594
# _update_merge_graph 0.07338285446166992
# _find_lowest_cost_edges 0.0017313957214355469
# --------- step:  306 ---------
# _merge_nodes 0.023833513259887695
# _update_merge_graph 0.04666018486022949
# _find_lowest_cost_edges 0.005387067794799805
# --------- step:  307 ---------
# _merge_nodes 0.012469053268432617
# _update_merge_graph 0.04284262657165527
# _find_lowest_cost_edges 0.005843639373779297
# --------- step:  308 ---------
# _merge_nodes 0.013232231140136719
# _update_merge_graph 0.05575704574584961
# _find_lowest_cost_edges 0.002288341522216797
# --------- step:  309 ---------
# _merge_nodes 0.028134822845458984
# _update_merge_graph 0.07094240188598633
# _find_lowest_cost_edges 0.0029296875
# ...
# _update_merge_graph 0.03643226623535156
# _find_lowest_cost_edges 0.004077434539794922
# --------- step:  400 ---------
# _merge_nodes 0.013882875442504883
# _update_merge_graph 0.0382840633392334
# _find_lowest_cost_edges 0.003509998321533203
# --------- step:  401 ---------
# _merge_nodes 0.013279438018798828
# _update_merge_graph 0.04501676559448242
# _find_lowest_cost_edges 0.0019390583038330078
# --------- step:  402 ---------
# _merge_nodes 0.018024444580078125
# _update_merge_graph 0.06526827812194824
# _find_lowest_cost_edges 0.003023386001586914
# --------- step:  403 ---------
# _merge_nodes 0.031804800033569336
# _update_merge_graph 0.04997754096984863
# _find_lowest_cost_edges 0.004241466522216797
# --------- step:  404 ---------
# _merge_nodes 0.012048959732055664
# _update_merge_graph 0.037017822265625
# _find_lowest_cost_edges 0.004244327545166016
# --------- step:  405 ---------
# _merge_nodes 0.012851715087890625
# _update_merge_graph 0.037825822830200195
# _find_lowest_cost_edges 0.004651308059692383
# --------- step:  406 ---------
# _merge_nodes 0.013172388076782227
# _update_merge_graph 0.04193925857543945
# _find_lowest_cost_edges 0.0032889842987060547
# --------- step:  407 ---------
# _merge_nodes 0.016750097274780273
# _update_merge_graph 0.04057621955871582
# _find_lowest_cost_edges 0.004725933074951172
# --------- step:  408 ---------
# _merge_nodes 0.014724254608154297
# _update_merge_graph 0.04167628288269043
# _find_lowest_cost_edges 0.004083156585693359
# --------- step:  409 ---------
# _merge_nodes 0.018800973892211914
# _update_merge_graph 0.05395698547363281
# _find_lowest_cost_edges 0.0049169063568115234
# --------- step:  410 ---------
# _merge_nodes 0.022839784622192383
# _update_merge_graph 0.057082414627075195
# _find_lowest_cost_edges 0.0017321109771728516
# --------- step:  411 ---------
# _merge_nodes 0.02515387535095215
# _update_merge_graph 0.05727696418762207
# _find_lowest_cost_edges 0.0023736953735351562
# --------- step:  412 ---------
# _merge_nodes 0.03663372993469238
# _update_merge_graph 0.05581545829772949
# _find_lowest_cost_edges 0.004510641098022461
# --------- step:  413 ---------
# _merge_nodes 0.015466690063476562
# _update_merge_graph 0.038694143295288086
# _find_lowest_cost_edges 0.0048580169677734375
# --------- step:  414 ---------
# _merge_nodes 0.02917623519897461
# _update_merge_graph 0.04946470260620117
# _find_lowest_cost_edges 0.004760265350341797
# --------- step:  415 ---------
# _merge_nodes 0.012176036834716797
# _update_merge_graph 0.03780961036682129
# _find_lowest_cost_edges 0.004784345626831055
# --------- step:  416 ---------
# _merge_nodes 0.01441502571105957
# _update_merge_graph 0.03954362869262695
# _find_lowest_cost_edges 0.004672527313232422
# --------- step:  417 ---------
# _merge_nodes 0.012676715850830078
# _update_merge_graph 0.03745150566101074
# _find_lowest_cost_edges 0.004558086395263672
# --------- step:  418 ---------
# _merge_nodes 0.012872934341430664
# _update_merge_graph 0.04155874252319336
# _find_lowest_cost_edges 0.003865957260131836
# --------- step:  419 ---------
# _merge_nodes 0.014533758163452148
# _update_merge_graph 0.03687644004821777
# _find_lowest_cost_edges 0.0048160552978515625
# --------- step:  420 ---------
# _merge_nodes 0.012072086334228516
# _update_merge_graph 0.038907766342163086
# _find_lowest_cost_edges 0.003981351852416992
# --------- step:  421 ---------
# _merge_nodes 0.038094282150268555
# _update_merge_graph 0.04029273986816406
# _find_lowest_cost_edges 0.004001140594482422
# --------- step:  422 ---------
# _merge_nodes 0.01715564727783203
# _update_merge_graph 0.04436063766479492
# _find_lowest_cost_edges 0.0032215118408203125
# --------- step:  423 ---------
# _merge_nodes 0.03529977798461914
# _update_merge_graph 0.03633880615234375
# _find_lowest_cost_edges 0.004761457443237305
# --------- step:  424 ---------
# _merge_nodes 0.012734651565551758
# _update_merge_graph 0.03849434852600098
# _find_lowest_cost_edges 0.004491090774536133
# --------- step:  425 ---------
# _merge_nodes 0.014445781707763672
# _update_merge_graph 0.03918623924255371
# _find_lowest_cost_edges 0.004442453384399414
# --------- step:  426 ---------
# _merge_nodes 0.013674736022949219
# _update_merge_graph 0.06280899047851562
# _find_lowest_cost_edges 0.0013794898986816406
# --------- step:  427 ---------
# _merge_nodes 0.012360095977783203
# _update_merge_graph 0.0350799560546875
# _find_lowest_cost_edges 0.004780292510986328
# --------- step:  428 ---------
# _merge_nodes 0.01144099235534668
# _update_merge_graph 0.03925752639770508
# _find_lowest_cost_edges 0.004319429397583008
# --------- step:  429 ---------
# _merge_nodes 0.018519163131713867
# _update_merge_graph 0.04681229591369629
# _find_lowest_cost_edges 0.0033769607543945312
# --------- step:  430 ---------
# _merge_nodes 0.018219709396362305
# _update_merge_graph 0.04535412788391113
# _find_lowest_cost_edges 0.0037457942962646484
# --------- step:  431 ---------
# _merge_nodes 0.017920494079589844
# _update_merge_graph 0.0415501594543457
# _find_lowest_cost_edges 0.004951953887939453
# --------- step:  432 ---------
# _merge_nodes 0.015023231506347656
# _update_merge_graph 0.035936832427978516
# _find_lowest_cost_edges 0.004427194595336914
# --------- step:  433 ---------
# _merge_nodes 0.014406681060791016
# _update_merge_graph 0.051073551177978516
# _find_lowest_cost_edges 0.004071474075317383
# --------- step:  434 ---------
# _merge_nodes 0.018596172332763672
# _update_merge_graph 0.03851938247680664
# _find_lowest_cost_edges 0.004167079925537109
# --------- step:  435 ---------
# _merge_nodes 0.029143571853637695
# _update_merge_graph 0.03946065902709961
# _find_lowest_cost_edges 0.004788875579833984
# --------- step:  436 ---------
# _merge_nodes 0.01147770881652832
# _update_merge_graph 0.03624606132507324
# _find_lowest_cost_edges 0.0046083927154541016
# --------- step:  437 ---------
# _merge_nodes 0.01102590560913086
# _update_merge_graph 0.055251121520996094
# _find_lowest_cost_edges 0.002190113067626953
# --------- step:  438 ---------
# _merge_nodes 0.011572599411010742
# _update_merge_graph 0.03468179702758789
# _find_lowest_cost_edges 0.004383087158203125
# --------- step:  439 ---------
# _merge_nodes 0.011846303939819336
# _update_merge_graph 0.03533434867858887
# _find_lowest_cost_edges 0.004467964172363281
# --------- step:  440 ---------
# _merge_nodes 0.011710405349731445
# _update_merge_graph 0.03767800331115723
# _find_lowest_cost_edges 0.0040357112884521484
# --------- step:  441 ---------
# _merge_nodes 0.012964010238647461
# _update_merge_graph 0.036164283752441406
# _find_lowest_cost_edges 0.004056215286254883
# --------- step:  442 ---------
# _merge_nodes 0.011909961700439453
# _update_merge_graph 0.03302168846130371
# _find_lowest_cost_edges 0.004483222961425781
# --------- step:  443 ---------
# _merge_nodes 0.010404109954833984
# _update_merge_graph 0.04252886772155762
# _find_lowest_cost_edges 0.00157928466796875
# --------- step:  444 ---------
# _merge_nodes 0.011709213256835938
# _update_merge_graph 0.03457760810852051
# _find_lowest_cost_edges 0.004134178161621094
# --------- step:  445 ---------
# _merge_nodes 0.012134075164794922
# _update_merge_graph 0.03698539733886719
# _find_lowest_cost_edges 0.004061698913574219
# --------- step:  446 ---------
# _merge_nodes 0.014798641204833984
# _update_merge_graph 0.05458855628967285
# _find_lowest_cost_edges 0.0034263134002685547
# --------- step:  447 ---------
# _merge_nodes 0.0330197811126709
# _update_merge_graph 0.05078911781311035
# _find_lowest_cost_edges 0.0035552978515625
# --------- step:  448 ---------
# _merge_nodes 0.01657247543334961
# _update_merge_graph 0.04073905944824219
# _find_lowest_cost_edges 0.003640413284301758
# --------- step:  449 ---------
# _merge_nodes 0.014321088790893555
# _update_merge_graph 0.03339529037475586
# _find_lowest_cost_edges 0.003953695297241211
# --------- step:  450 ---------
# _merge_nodes 0.011461734771728516
# _update_merge_graph 0.03328371047973633
# _find_lowest_cost_edges 0.004126310348510742
# --------- step:  451 ---------
# _merge_nodes 0.010616779327392578
# _update_merge_graph 0.04286479949951172
# _find_lowest_cost_edges 0.003132343292236328
# --------- step:  452 ---------
# _merge_nodes 0.016225576400756836
# _update_merge_graph 0.04136490821838379
# _find_lowest_cost_edges 0.002791166305541992
# --------- step:  453 ---------
# _merge_nodes 0.01791071891784668
# _update_merge_graph 0.03531980514526367
# _find_lowest_cost_edges 0.0037326812744140625
# --------- step:  454 ---------
# _merge_nodes 0.011879920959472656
# _update_merge_graph 0.03884100914001465
# _find_lowest_cost_edges 0.002676725387573242
# --------- step:  455 ---------
# _merge_nodes 0.012055158615112305
# _update_merge_graph 0.04023265838623047
# _find_lowest_cost_edges 0.0033440589904785156
# --------- step:  456 ---------
# _merge_nodes 0.0138397216796875
# _update_merge_graph 0.03695106506347656
# _find_lowest_cost_edges 0.0039768218994140625
# --------- step:  457 ---------
# _merge_nodes 0.012281179428100586
# _update_merge_graph 0.03837394714355469
# _find_lowest_cost_edges 0.002601146697998047
# --------- step:  458 ---------
# _merge_nodes 0.012618541717529297
# _update_merge_graph 0.04738259315490723
# _find_lowest_cost_edges 0.0020685195922851562
# --------- step:  459 ---------
# _merge_nodes 0.012350797653198242
# _update_merge_graph 0.042104244232177734
# _find_lowest_cost_edges 0.002518177032470703
# --------- step:  460 ---------
# _merge_nodes 0.011325836181640625
# _update_merge_graph 0.03500676155090332
# _find_lowest_cost_edges 0.0034058094024658203
# --------- step:  461 ---------
# _merge_nodes 0.014060497283935547
# _update_merge_graph 0.03464508056640625
# _find_lowest_cost_edges 0.003429889678955078
# --------- step:  462 ---------
# _merge_nodes 0.012722253799438477
# _update_merge_graph 0.03565621376037598
# _find_lowest_cost_edges 0.0035817623138427734
# --------- step:  463 ---------
# _merge_nodes 0.01228642463684082
# _update_merge_graph 0.0423734188079834
# _find_lowest_cost_edges 0.0013005733489990234
# --------- step:  464 ---------
# _merge_nodes 0.011430978775024414
# _update_merge_graph 0.034510135650634766
# _find_lowest_cost_edges 0.0036423206329345703
# --------- step:  465 ---------
# _merge_nodes 0.012790918350219727
# _update_merge_graph 0.035131216049194336
# _find_lowest_cost_edges 0.0034246444702148438
# --------- step:  466 ---------
# _merge_nodes 0.012742042541503906
# _update_merge_graph 0.032414913177490234
# _find_lowest_cost_edges 0.003126382827758789
# --------- step:  467 ---------
# _merge_nodes 0.025685787200927734
# _update_merge_graph 0.035967350006103516
# _find_lowest_cost_edges 0.003423452377319336
# --------- step:  468 ---------
# _merge_nodes 0.011577367782592773
# _update_merge_graph 0.03148603439331055
# _find_lowest_cost_edges 0.00331878662109375
# --------- step:  469 ---------
# _merge_nodes 0.011175155639648438
# _update_merge_graph 0.03558063507080078
# _find_lowest_cost_edges 0.002124309539794922
# --------- step:  470 ---------
# _merge_nodes 0.012185096740722656
# _update_merge_graph 0.032466888427734375
# _find_lowest_cost_edges 0.002744913101196289
# --------- step:  471 ---------
# _merge_nodes 0.01196432113647461
# _update_merge_graph 0.03543710708618164
# _find_lowest_cost_edges 0.002252817153930664
# --------- step:  472 ---------
# _merge_nodes 0.015367746353149414
# _update_merge_graph 0.03598833084106445
# _find_lowest_cost_edges 0.002821683883666992
# --------- step:  473 ---------
# _merge_nodes 0.014137744903564453
# _update_merge_graph 0.05411553382873535
# _find_lowest_cost_edges 0.002330303192138672
# --------- step:  474 ---------
# _merge_nodes 0.02479863166809082
# _update_merge_graph 0.03464984893798828
# _find_lowest_cost_edges 0.0027375221252441406
# --------- step:  475 ---------
# _merge_nodes 0.017708301544189453
# _update_merge_graph 0.04180717468261719
# _find_lowest_cost_edges 0.0016279220581054688
# --------- step:  476 ---------
# _merge_nodes 0.017774105072021484
# _update_merge_graph 0.03432583808898926
# _find_lowest_cost_edges 0.002444744110107422
# --------- step:  477 ---------
# _merge_nodes 0.012309789657592773
# _update_merge_graph 0.03473019599914551
# _find_lowest_cost_edges 0.0011973381042480469
# --------- step:  478 ---------
# _merge_nodes 0.01631474494934082
# _update_merge_graph 0.03717231750488281
# _find_lowest_cost_edges 0.0026209354400634766
# --------- step:  479 ---------
# _merge_nodes 0.012381553649902344
# _update_merge_graph 0.03300881385803223
# _find_lowest_cost_edges 0.0021457672119140625
# --------- step:  480 ---------
# _merge_nodes 0.014166593551635742
# _update_merge_graph 0.034653425216674805
# _find_lowest_cost_edges 0.0013933181762695312
# --------- step:  481 ---------
# _merge_nodes 0.014816522598266602
# _update_merge_graph 0.04001760482788086
# _find_lowest_cost_edges 0.0018432140350341797
# --------- step:  482 ---------
# _merge_nodes 0.015882492065429688
# _update_merge_graph 0.036329030990600586
# _find_lowest_cost_edges 0.002600431442260742
# --------- step:  483 ---------
# _merge_nodes 0.012555837631225586
# _update_merge_graph 0.034049034118652344
# _find_lowest_cost_edges 0.0010383129119873047
# --------- step:  484 ---------
# _merge_nodes 0.02672719955444336
# _update_merge_graph 0.03774142265319824
# _find_lowest_cost_edges 0.0019369125366210938
# --------- step:  485 ---------
# _merge_nodes 0.012233495712280273
# _update_merge_graph 0.030765771865844727
# _find_lowest_cost_edges 0.001928091049194336
# --------- step:  486 ---------
# _merge_nodes 0.011482715606689453
# _update_merge_graph 0.030228614807128906
# _find_lowest_cost_edges 0.0012793540954589844
# --------- step:  487 ---------
# _merge_nodes 0.012073516845703125
# _update_merge_graph 0.028583049774169922
# _find_lowest_cost_edges 0.0022237300872802734
# --------- step:  488 ---------
# _merge_nodes 0.01221776008605957
# _update_merge_graph 0.03186440467834473
# _find_lowest_cost_edges 0.001825571060180664
# --------- step:  489 ---------
# _merge_nodes 0.013697147369384766
# _update_merge_graph 0.03833270072937012
# _find_lowest_cost_edges 0.003210306167602539
# --------- step:  490 ---------
# _merge_nodes 0.023772716522216797
# _update_merge_graph 0.04055976867675781
# _find_lowest_cost_edges 0.0012030601501464844
# --------- step:  491 ---------
# _merge_nodes 0.02263951301574707
# _update_merge_graph 0.03973650932312012
# _find_lowest_cost_edges 0.001238107681274414
# --------- step:  492 ---------
# _merge_nodes 0.023411273956298828
# _update_merge_graph 0.03998684883117676
# _find_lowest_cost_edges 0.0012888908386230469
# --------- step:  493 ---------
# _merge_nodes 0.02205634117126465
# _update_merge_graph 0.06232118606567383
# _find_lowest_cost_edges 0.0033032894134521484
# --------- step:  494 ---------
# _merge_nodes 0.019397974014282227
# _update_merge_graph 0.04253268241882324
# _find_lowest_cost_edges 0.005124330520629883
# --------- step:  495 ---------
# _merge_nodes 0.01322627067565918
# _update_merge_graph 0.04241633415222168
# _find_lowest_cost_edges 0.004294395446777344
# --------- step:  496 ---------
# _merge_nodes 0.021332740783691406
# _update_merge_graph 0.04737257957458496
# _find_lowest_cost_edges 0.0032341480255126953
# --------- step:  497 ---------
# _merge_nodes 0.013422012329101562
# _update_merge_graph 0.040834903717041016
# _find_lowest_cost_edges 0.004185199737548828
# --------- step:  498 ---------
# _merge_nodes 0.022551774978637695
# _update_merge_graph 0.05475783348083496
# _find_lowest_cost_edges 0.004453897476196289
# --------- step:  499 ---------
# _merge_nodes 0.016381502151489258
# _update_merge_graph 0.04266810417175293
# _find_lowest_cost_edges 0.004277944564819336
# --------- step:  500 ---------
# ratio 0.09828674481514878
#
# ========== Run 1 ==========
#
# Original Graph Accuracy:   0.6687
# Coarsened Graph Accuracy:  0.6657
# Inverted Coarsened Accuracy: 0.6281
#
# ========== Run 2 ==========
#
# Original Graph Accuracy:   0.6988
# Coarsened Graph Accuracy:  0.6024
# Inverted Coarsened Accuracy: 0.6139
#
# ========== Run 3 ==========
#
# Original Graph Accuracy:   0.6867
# Coarsened Graph Accuracy:  0.6416
# Inverted Coarsened Accuracy: 0.5986
#
# ========== Run 4 ==========
#
# Original Graph Accuracy:   0.6807
# Coarsened Graph Accuracy:  0.6777
# Inverted Coarsened Accuracy: 0.6173
#
# ========== Run 5 ==========
#
# Original Graph Accuracy:   0.6596
# Coarsened Graph Accuracy:  0.6145
# Inverted Coarsened Accuracy: 0.6022
#
# Original Graph Accuracy:
#   Mean: 0.6789
#   Std:  0.0137
#
# Coarsened Graph Accuracy:
#   Mean: 0.6404
#   Std:  0.0288
#
# Inverted Accuracy:
#   Mean: 0.6120
#   Std:  0.0106

# %%
R = {
    "paper": 0,
    "cited-by":0,
    "cites":1,

    
}
coarsener = HeteroCoarsener(None,original_graph, 0.1, num_nearest_per_etype=30, num_nearest_neighbors=30,pairs_per_level=10, is_neighboring_h= False, R=R) #
coarsener.init_step()
isNewMerges = True
for i in range(1000):
    if not isNewMerges:
        break
    print("--------- step: " , i , "---------" )
    isNewMerges = coarsener.iteration_step()

coarsend_graph = coarsener.get_coarsend_graph()
coarsend_graph = coarsend_graph.cpu()
mapping = coarsener.get_mapping("paper")
labels = coarsener._get_labels(mapping, "paper")
coarsend_graph.nodes["paper"].data["label"] = torch.tensor([labels[i] for i in range(len(labels))])
print("ratio", coarsend_graph.num_nodes()/ original_graph.num_nodes() ) 

run_multiple_experiments(
    original_graph=original_graph,
    coarsend_graph=coarsend_graph,
    mapping=mapping,
    get_splits_and_labels=get_splits_and_labels,
    model_class=HeteroGCNCiteer,  # or ImprovedHeteroGNN if needed
    num_runs=5,
    epochs=150
)
# Out:
# /home/robin/thesis/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:108: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   deg_out = torch.tensor(self.node_degrees[etype]['out'], device=self.device) + 1.0
# /home/robin/thesis/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   deg_in  = torch.tensor(self.node_degrees[etype]['in'], device=self.device)  + 1.0
# _create_h_spatial_rgcn 0.0037908554077148438
# _init_costs 0.5111360549926758
# _get_union 0.8965177536010742
# _costs_of_merges 1.528153657913208
# _init_merge_graph 0.0017833709716796875
# _find_lowest_cost_edges 0.0011873245239257812
# --------- step:  0 ---------
# _merge_nodes 0.007738351821899414
# _update_merge_graph 0.13765764236450195
# _find_lowest_cost_edges 0.003663778305053711
# --------- step:  1 ---------
# _merge_nodes 0.009668111801147461
# /home/robin/thesis/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:609: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   node1s = torch.tensor(node1s, dtype=torch.long)
# /home/robin/thesis/convolution-matching/GraphSummarizers/Coarsener/HeteroCoarsener.py:610: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   node2s = torch.tensor(node2s, dtype=torch.long)
# _update_merge_graph 0.025066614151000977
# _find_lowest_cost_edges 0.002809762954711914
# --------- step:  2 ---------
# _merge_nodes 0.010076522827148438
# _update_merge_graph 0.02284073829650879
# _find_lowest_cost_edges 0.0033648014068603516
# --------- step:  3 ---------
# _merge_nodes 0.007615566253662109
# _update_merge_graph 0.021021604537963867
# _find_lowest_cost_edges 0.0035233497619628906
# --------- step:  4 ---------
# _merge_nodes 0.006868124008178711
# _update_merge_graph 0.021582365036010742
# _find_lowest_cost_edges 0.0033566951751708984
# --------- step:  5 ---------
# _merge_nodes 0.007633209228515625
# _update_merge_graph 0.02542257308959961
# _find_lowest_cost_edges 0.002025604248046875
# --------- step:  6 ---------
# _merge_nodes 0.008369922637939453
# _update_merge_graph 0.024696826934814453
# _find_lowest_cost_edges 0.0024309158325195312
# --------- step:  7 ---------
# _merge_nodes 0.011283397674560547
# _update_merge_graph 0.022429704666137695
# _find_lowest_cost_edges 0.0033512115478515625
# --------- step:  8 ---------
# _merge_nodes 0.008365869522094727
# _update_merge_graph 0.02163863182067871
# _find_lowest_cost_edges 0.003297567367553711
# --------- step:  9 ---------
# _merge_nodes 0.007297515869140625
# _update_merge_graph 0.02123236656188965
# _find_lowest_cost_edges 0.0033593177795410156
# --------- step:  10 ---------
# _merge_nodes 0.0071833133697509766
# _update_merge_graph 0.021193742752075195
# _find_lowest_cost_edges 0.0033240318298339844
# --------- step:  11 ---------
# _merge_nodes 0.006591081619262695
# _update_merge_graph 0.024236202239990234
# _find_lowest_cost_edges 0.0027310848236083984
# --------- step:  12 ---------
# _merge_nodes 0.008149147033691406
# _update_merge_graph 0.02057957649230957
# _find_lowest_cost_edges 0.0034682750701904297
# --------- step:  13 ---------
# _merge_nodes 0.006916999816894531
# _update_merge_graph 0.02082657814025879
# _find_lowest_cost_edges 0.003339529037475586
# --------- step:  14 ---------
# _merge_nodes 0.008111238479614258
# _update_merge_graph 0.020940065383911133
# _find_lowest_cost_edges 0.0032029151916503906
# --------- step:  15 ---------
# _merge_nodes 0.007483720779418945
# _update_merge_graph 0.019922494888305664
# _find_lowest_cost_edges 0.0031671524047851562
# --------- step:  16 ---------
# _merge_nodes 0.007301807403564453
# _update_merge_graph 0.02158069610595703
# _find_lowest_cost_edges 0.0028862953186035156
# --------- step:  17 ---------
# _merge_nodes 0.006722211837768555
# _update_merge_graph 0.023499250411987305
# _find_lowest_cost_edges 0.0028781890869140625
# --------- step:  18 ---------
# _merge_nodes 0.011475086212158203
# _update_merge_graph 0.03722071647644043
# _find_lowest_cost_edges 0.003444194793701172
# --------- step:  19 ---------
# _merge_nodes 0.009621143341064453
# _update_merge_graph 0.021898269653320312
# _find_lowest_cost_edges 0.003207683563232422
# --------- step:  20 ---------
# _merge_nodes 0.00745081901550293
# _update_merge_graph 0.02407050132751465
# _find_lowest_cost_edges 0.002482175827026367
# --------- step:  21 ---------
# _merge_nodes 0.011800765991210938
# _update_merge_graph 0.02106189727783203
# _find_lowest_cost_edges 0.0028870105743408203
# --------- step:  22 ---------
# _merge_nodes 0.009445667266845703
# _update_merge_graph 0.02071523666381836
# _find_lowest_cost_edges 0.0028655529022216797
# --------- step:  23 ---------
# _merge_nodes 0.008062124252319336
# _update_merge_graph 0.021394729614257812
# _find_lowest_cost_edges 0.002750396728515625
# --------- step:  24 ---------
# _merge_nodes 0.007662773132324219
# _update_merge_graph 0.020663022994995117
# _find_lowest_cost_edges 0.003048419952392578
# --------- step:  25 ---------
# _merge_nodes 0.007454395294189453
# _update_merge_graph 0.023241281509399414
# _find_lowest_cost_edges 0.0020885467529296875
# --------- step:  26 ---------
# _merge_nodes 0.007135868072509766
# _update_merge_graph 0.019717931747436523
# _find_lowest_cost_edges 0.003100156784057617
# --------- step:  27 ---------
# _merge_nodes 0.007817268371582031
# _update_merge_graph 0.023430824279785156
# _find_lowest_cost_edges 0.0026357173919677734
# --------- step:  28 ---------
# _merge_nodes 0.010366439819335938
# _update_merge_graph 0.022829294204711914
# _find_lowest_cost_edges 0.003083467483520508
# --------- step:  29 ---------
# _merge_nodes 0.00680994987487793
# _update_merge_graph 0.02205824851989746
# _find_lowest_cost_edges 0.002872467041015625
# --------- step:  30 ---------
# _merge_nodes 0.009441852569580078
# _update_merge_graph 0.025147676467895508
# _find_lowest_cost_edges 0.0023238658905029297
# --------- step:  31 ---------
# _merge_nodes 0.007767915725708008
# _update_merge_graph 0.020801544189453125
# _find_lowest_cost_edges 0.0028870105743408203
# --------- step:  32 ---------
# _merge_nodes 0.007094383239746094
# _update_merge_graph 0.02053070068359375
# _find_lowest_cost_edges 0.0029196739196777344
# --------- step:  33 ---------
# _merge_nodes 0.007344961166381836
# _update_merge_graph 0.02062535285949707
# _find_lowest_cost_edges 0.0031125545501708984
# --------- step:  34 ---------
# _merge_nodes 0.007027387619018555
# _update_merge_graph 0.019732952117919922
# _find_lowest_cost_edges 0.002565622329711914
# --------- step:  35 ---------
# _merge_nodes 0.006932735443115234
# _update_merge_graph 0.020708560943603516
# _find_lowest_cost_edges 0.002978801727294922
# --------- step:  36 ---------
# _merge_nodes 0.007240772247314453
# _update_merge_graph 0.021533727645874023
# _find_lowest_cost_edges 0.0029189586639404297
# --------- step:  37 ---------
# _merge_nodes 0.007024526596069336
# _update_merge_graph 0.020044565200805664
# _find_lowest_cost_edges 0.0028929710388183594
# --------- step:  38 ---------
# _merge_nodes 0.007200717926025391
# _update_merge_graph 0.020572423934936523
# _find_lowest_cost_edges 0.002836465835571289
# --------- step:  39 ---------
# _merge_nodes 0.0072917938232421875
# _update_merge_graph 0.01996612548828125
# _find_lowest_cost_edges 0.003092050552368164
# --------- step:  40 ---------
# _merge_nodes 0.007942914962768555
# _update_merge_graph 0.021021604537963867
# _find_lowest_cost_edges 0.0033609867095947266
# --------- step:  41 ---------
# _merge_nodes 0.008050203323364258
# _update_merge_graph 0.03469204902648926
# _find_lowest_cost_edges 0.0022106170654296875
# --------- step:  42 ---------
# _merge_nodes 0.019085407257080078
# _update_merge_graph 0.030033111572265625
# _find_lowest_cost_edges 0.0025637149810791016
# --------- step:  43 ---------
# _merge_nodes 0.00696110725402832
# _update_merge_graph 0.019731998443603516
# _find_lowest_cost_edges 0.002752065658569336
# --------- step:  44 ---------
# _merge_nodes 0.0067462921142578125
# _update_merge_graph 0.020684003829956055
# _find_lowest_cost_edges 0.002880573272705078
# --------- step:  45 ---------
# _merge_nodes 0.008312702178955078
# _update_merge_graph 0.02510523796081543
# _find_lowest_cost_edges 0.0029065608978271484
# --------- step:  46 ---------
# _merge_nodes 0.007486104965209961
# _update_merge_graph 0.019433975219726562
# _find_lowest_cost_edges 0.003105640411376953
# --------- step:  47 ---------
# _merge_nodes 0.007498264312744141
# _update_merge_graph 0.023676633834838867
# _find_lowest_cost_edges 0.0028324127197265625
# --------- step:  48 ---------
# _merge_nodes 0.007447957992553711
# _update_merge_graph 0.021508216857910156
# _find_lowest_cost_edges 0.0029320716857910156
# --------- step:  49 ---------
# _merge_nodes 0.006830692291259766
# _update_merge_graph 0.021952152252197266
# _find_lowest_cost_edges 0.0026755332946777344
# --------- step:  50 ---------
# _merge_nodes 0.009306192398071289
# _update_merge_graph 0.020152807235717773
# _find_lowest_cost_edges 0.002849578857421875
# --------- step:  51 ---------
# _merge_nodes 0.0069122314453125
# _update_merge_graph 0.01925516128540039
# _find_lowest_cost_edges 0.0028510093688964844
# --------- step:  52 ---------
# _merge_nodes 0.007712841033935547
# _update_merge_graph 0.02069711685180664
# _find_lowest_cost_edges 0.0029518604278564453
# --------- step:  53 ---------
# _merge_nodes 0.007059574127197266
# _update_merge_graph 0.018998384475708008
# _find_lowest_cost_edges 0.002897977828979492
# --------- step:  54 ---------
# _merge_nodes 0.007234811782836914
# _update_merge_graph 0.020437002182006836
# _find_lowest_cost_edges 0.002718687057495117
# --------- step:  55 ---------
# _merge_nodes 0.007637500762939453
# _update_merge_graph 0.022441625595092773
# _find_lowest_cost_edges 0.0028345584869384766
# --------- step:  56 ---------
# _merge_nodes 0.007195949554443359
# _update_merge_graph 0.020114898681640625
# _find_lowest_cost_edges 0.0029141902923583984
# --------- step:  57 ---------
# _merge_nodes 0.00703883171081543
# _update_merge_graph 0.021185636520385742
# _find_lowest_cost_edges 0.0030486583709716797
# --------- step:  58 ---------
# _merge_nodes 0.006560087203979492
# _update_merge_graph 0.019727468490600586
# _find_lowest_cost_edges 0.003126859664916992
# --------- step:  59 ---------
# _merge_nodes 0.007586479187011719
# _update_merge_graph 0.021013498306274414
# _find_lowest_cost_edges 0.003020048141479492
# --------- step:  60 ---------
# _merge_nodes 0.007523536682128906
# _update_merge_graph 0.023177385330200195
# _find_lowest_cost_edges 0.0029141902923583984
# --------- step:  61 ---------
# _merge_nodes 0.007036685943603516
# _update_merge_graph 0.020795583724975586
# _find_lowest_cost_edges 0.0027790069580078125
# --------- step:  62 ---------
# _merge_nodes 0.007041454315185547
# _update_merge_graph 0.02335500717163086
# _find_lowest_cost_edges 0.0027971267700195312
# --------- step:  63 ---------
# _merge_nodes 0.01007223129272461
# _update_merge_graph 0.02593827247619629
# _find_lowest_cost_edges 0.0015349388122558594
# --------- step:  64 ---------
# _merge_nodes 0.010321617126464844
# _update_merge_graph 0.024103403091430664
# _find_lowest_cost_edges 0.0028154850006103516
# --------- step:  65 ---------
# _merge_nodes 0.009505987167358398
# _update_merge_graph 0.018973350524902344
# _find_lowest_cost_edges 0.0029604434967041016
# --------- step:  66 ---------
# _merge_nodes 0.006812334060668945
# _update_merge_graph 0.019917726516723633
# _find_lowest_cost_edges 0.002491474151611328
# --------- step:  67 ---------
# _merge_nodes 0.006857872009277344
# _update_merge_graph 0.019243717193603516
# _find_lowest_cost_edges 0.0029082298278808594
# --------- step:  68 ---------
# _merge_nodes 0.006558895111083984
# _update_merge_graph 0.019518136978149414
# _find_lowest_cost_edges 0.0027141571044921875
# --------- step:  69 ---------
# _merge_nodes 0.0067555904388427734
# _update_merge_graph 0.019066810607910156
# _find_lowest_cost_edges 0.0028645992279052734
# --------- step:  70 ---------
# _merge_nodes 0.007005453109741211
# _update_merge_graph 0.02267599105834961
# _find_lowest_cost_edges 0.00281524658203125
# --------- step:  71 ---------
# _merge_nodes 0.00658106803894043
# _update_merge_graph 0.02048492431640625
# _find_lowest_cost_edges 0.0027992725372314453
# --------- step:  72 ---------
# _merge_nodes 0.007216215133666992
# _update_merge_graph 0.019719600677490234
# _find_lowest_cost_edges 0.002567291259765625
# --------- step:  73 ---------
# _merge_nodes 0.009540081024169922
# _update_merge_graph 0.02422809600830078
# _find_lowest_cost_edges 0.0026941299438476562
# --------- step:  74 ---------
# _merge_nodes 0.00951838493347168
# _update_merge_graph 0.02267622947692871
# _find_lowest_cost_edges 0.0011148452758789062
# --------- step:  75 ---------
# _merge_nodes 0.00716710090637207
# _update_merge_graph 0.021160602569580078
# _find_lowest_cost_edges 0.002504587173461914
# --------- step:  76 ---------
# _merge_nodes 0.006494998931884766
# _update_merge_graph 0.0197601318359375
# _find_lowest_cost_edges 0.0028586387634277344
# --------- step:  77 ---------
# _merge_nodes 0.006829261779785156
# _update_merge_graph 0.019692182540893555
# _find_lowest_cost_edges 0.0030050277709960938
# --------- step:  78 ---------
# _merge_nodes 0.007695198059082031
# _update_merge_graph 0.020140647888183594
# _find_lowest_cost_edges 0.0027189254760742188
# --------- step:  79 ---------
# _merge_nodes 0.007771968841552734
# _update_merge_graph 0.021234512329101562
# _find_lowest_cost_edges 0.0025527477264404297
# --------- step:  80 ---------
# _merge_nodes 0.007869958877563477
# _update_merge_graph 0.02983689308166504
# _find_lowest_cost_edges 0.002124309539794922
# --------- step:  81 ---------
# _merge_nodes 0.01776266098022461
# _update_merge_graph 0.01997852325439453
# _find_lowest_cost_edges 0.0028192996978759766
# --------- step:  82 ---------
# _merge_nodes 0.007350921630859375
# _update_merge_graph 0.024646759033203125
# _find_lowest_cost_edges 0.0019855499267578125
# --------- step:  83 ---------
# _merge_nodes 0.019835710525512695
# _update_merge_graph 0.023568153381347656
# _find_lowest_cost_edges 0.0026166439056396484
# --------- step:  84 ---------
# _merge_nodes 0.009032011032104492
# _update_merge_graph 0.023935317993164062
# _find_lowest_cost_edges 0.002068758010864258
# --------- step:  85 ---------
# _merge_nodes 0.0072917938232421875
# _update_merge_graph 0.01979517936706543
# _find_lowest_cost_edges 0.0029201507568359375
# --------- step:  86 ---------
# _merge_nodes 0.007497549057006836
# _update_merge_graph 0.028992891311645508
# _find_lowest_cost_edges 0.0024771690368652344
# --------- step:  87 ---------
# _merge_nodes 0.008684396743774414
# _update_merge_graph 0.02094554901123047
# _find_lowest_cost_edges 0.002643585205078125
# --------- step:  88 ---------
# _merge_nodes 0.007763385772705078
# _update_merge_graph 0.02506542205810547
# _find_lowest_cost_edges 0.002269744873046875
# --------- step:  89 ---------
# _merge_nodes 0.008370399475097656
# _update_merge_graph 0.021130084991455078
# _find_lowest_cost_edges 0.0029299259185791016
# --------- step:  90 ---------
# _merge_nodes 0.007272005081176758
# _update_merge_graph 0.019603967666625977
# _find_lowest_cost_edges 0.003178834915161133
# --------- step:  91 ---------
# _merge_nodes 0.0072972774505615234
# _update_merge_graph 0.020020484924316406
# _find_lowest_cost_edges 0.003203868865966797
# --------- step:  92 ---------
# _merge_nodes 0.006998777389526367
# _update_merge_graph 0.020524263381958008
# _find_lowest_cost_edges 0.002855539321899414
# --------- step:  93 ---------
# _merge_nodes 0.006551504135131836
# _update_merge_graph 0.01933908462524414
# _find_lowest_cost_edges 0.003047943115234375
# --------- step:  94 ---------
# _merge_nodes 0.009016990661621094
# _update_merge_graph 0.02053546905517578
# _find_lowest_cost_edges 0.002893686294555664
# --------- step:  95 ---------
# _merge_nodes 0.010055780410766602
# _update_merge_graph 0.0246279239654541
# _find_lowest_cost_edges 0.002101898193359375
# --------- step:  96 ---------
# _merge_nodes 0.021028757095336914
# _update_merge_graph 0.024611473083496094
# _find_lowest_cost_edges 0.0026311874389648438
# --------- step:  97 ---------
# _merge_nodes 0.009385347366333008
# _update_merge_graph 0.02343273162841797
# _find_lowest_cost_edges 0.0027823448181152344
# --------- step:  98 ---------
# _merge_nodes 0.009030580520629883
# _update_merge_graph 0.020054340362548828
# _find_lowest_cost_edges 0.002929210662841797
# --------- step:  99 ---------
# _merge_nodes 0.008394002914428711
# _update_merge_graph 0.02267622947692871
# _find_lowest_cost_edges 0.003057241439819336
# --------- step:  100 ---------
# _merge_nodes 0.008744001388549805
# _update_merge_graph 0.02502608299255371
# _find_lowest_cost_edges 0.0024204254150390625
# --------- step:  101 ---------
# _merge_nodes 0.009322881698608398
# _update_merge_graph 0.021207332611083984
# _find_lowest_cost_edges 0.0027589797973632812
# --------- step:  102 ---------
# _merge_nodes 0.007550239562988281
# _update_merge_graph 0.022286653518676758
# _find_lowest_cost_edges 0.0022711753845214844
# --------- step:  103 ---------
# _merge_nodes 0.0077817440032958984
# _update_merge_graph 0.019690752029418945
# _find_lowest_cost_edges 0.0030291080474853516
# --------- step:  104 ---------
# _merge_nodes 0.007141828536987305
# _update_merge_graph 0.020464181900024414
# _find_lowest_cost_edges 0.0028934478759765625
# --------- step:  105 ---------
# _merge_nodes 0.007042646408081055
# _update_merge_graph 0.02088189125061035
# _find_lowest_cost_edges 0.002728700637817383
# --------- step:  106 ---------
# _merge_nodes 0.006951093673706055
# _update_merge_graph 0.022821664810180664
# _find_lowest_cost_edges 0.0030508041381835938
# --------- step:  107 ---------
# _merge_nodes 0.009754180908203125
# _update_merge_graph 0.024131298065185547
# _find_lowest_cost_edges 0.0022068023681640625
# --------- step:  108 ---------
# _merge_nodes 0.006797313690185547
# _update_merge_graph 0.025135278701782227
# _find_lowest_cost_edges 0.003066539764404297
# --------- step:  109 ---------
# _merge_nodes 0.008504390716552734
# _update_merge_graph 0.02144026756286621
# _find_lowest_cost_edges 0.0025513172149658203
# --------- step:  110 ---------
# _merge_nodes 0.00834965705871582
# _update_merge_graph 0.02250075340270996
# _find_lowest_cost_edges 0.0029153823852539062
# --------- step:  111 ---------
# _merge_nodes 0.00745391845703125
# _update_merge_graph 0.02056431770324707
# _find_lowest_cost_edges 0.0028791427612304688
# --------- step:  112 ---------
# _merge_nodes 0.007755279541015625
# _update_merge_graph 0.022301435470581055
# _find_lowest_cost_edges 0.002382993698120117
# --------- step:  113 ---------
# _merge_nodes 0.010268211364746094
# _update_merge_graph 0.021176576614379883
# _find_lowest_cost_edges 0.0028192996978759766
# --------- step:  114 ---------
# _merge_nodes 0.006964445114135742
# _update_merge_graph 0.020046710968017578
# _find_lowest_cost_edges 0.0028061866760253906
# --------- step:  115 ---------
# _merge_nodes 0.0103912353515625
# _update_merge_graph 0.022372007369995117
# _find_lowest_cost_edges 0.002849102020263672
# --------- step:  116 ---------
# _merge_nodes 0.009628057479858398
# _update_merge_graph 0.027981996536254883
# _find_lowest_cost_edges 0.0023941993713378906
# --------- step:  117 ---------
# _merge_nodes 0.008646726608276367
# _update_merge_graph 0.02616572380065918
# _find_lowest_cost_edges 0.0026340484619140625
# --------- step:  118 ---------
# _merge_nodes 0.008373737335205078
# _update_merge_graph 0.02880096435546875
# _find_lowest_cost_edges 0.0024929046630859375
# --------- step:  119 ---------
# _merge_nodes 0.00835561752319336
# _update_merge_graph 0.02022266387939453
# _find_lowest_cost_edges 0.0029032230377197266
# --------- step:  120 ---------
# _merge_nodes 0.007180213928222656
# _update_merge_graph 0.02007770538330078
# _find_lowest_cost_edges 0.0028276443481445312
# --------- step:  121 ---------
# _merge_nodes 0.007176399230957031
# _update_merge_graph 0.0218050479888916
# _find_lowest_cost_edges 0.002880573272705078
# --------- step:  122 ---------
# _merge_nodes 0.00718379020690918
# _update_merge_graph 0.022738933563232422
# _find_lowest_cost_edges 0.0028853416442871094
# --------- step:  123 ---------
# _merge_nodes 0.00677180290222168
# _update_merge_graph 0.024024009704589844
# _find_lowest_cost_edges 0.002000093460083008
# --------- step:  124 ---------
# _merge_nodes 0.0071926116943359375
# _update_merge_graph 0.020666837692260742
# _find_lowest_cost_edges 0.0028085708618164062
# --------- step:  125 ---------
# _merge_nodes 0.00871586799621582
# _update_merge_graph 0.02392101287841797
# _find_lowest_cost_edges 0.0027189254760742188
# --------- step:  126 ---------
# _merge_nodes 0.009437322616577148
# _update_merge_graph 0.023929595947265625
# _find_lowest_cost_edges 0.00276947021484375
# --------- step:  127 ---------
# _merge_nodes 0.008197784423828125
# _update_merge_graph 0.02278614044189453
# _find_lowest_cost_edges 0.002676725387573242
# --------- step:  128 ---------
# _merge_nodes 0.008257389068603516
# _update_merge_graph 0.023445606231689453
# _find_lowest_cost_edges 0.0031719207763671875
# --------- step:  129 ---------
# _merge_nodes 0.007670402526855469
# _update_merge_graph 0.02133464813232422
# _find_lowest_cost_edges 0.0029032230377197266
# --------- step:  130 ---------
# _merge_nodes 0.008256912231445312
# _update_merge_graph 0.022045373916625977
# _find_lowest_cost_edges 0.0029060840606689453
# --------- step:  131 ---------
# _merge_nodes 0.007682085037231445
# _update_merge_graph 0.021782875061035156
# _find_lowest_cost_edges 0.0030879974365234375
# --------- step:  132 ---------
# _merge_nodes 0.006867170333862305
# _update_merge_graph 0.021818876266479492
# _find_lowest_cost_edges 0.0026073455810546875
# --------- step:  133 ---------
# _merge_nodes 0.00833582878112793
# _update_merge_graph 0.02050471305847168
# _find_lowest_cost_edges 0.002843141555786133
# --------- step:  134 ---------
# _merge_nodes 0.007977008819580078
# _update_merge_graph 0.022072315216064453
# _find_lowest_cost_edges 0.0027878284454345703
# --------- step:  135 ---------
# _merge_nodes 0.007203578948974609
# _update_merge_graph 0.036124229431152344
# _find_lowest_cost_edges 0.001993417739868164
# --------- step:  136 ---------
# _merge_nodes 0.018434762954711914
# _update_merge_graph 0.022252321243286133
# _find_lowest_cost_edges 0.0029261112213134766
# --------- step:  137 ---------
# _merge_nodes 0.00786733627319336
# _update_merge_graph 0.021403789520263672
# _find_lowest_cost_edges 0.002560138702392578
# --------- step:  138 ---------
# _merge_nodes 0.007074832916259766
# _update_merge_graph 0.019648075103759766
# _find_lowest_cost_edges 0.002972841262817383
# --------- step:  139 ---------
# _merge_nodes 0.007043123245239258
# _update_merge_graph 0.021343708038330078
# _find_lowest_cost_edges 0.0027914047241210938
# --------- step:  140 ---------
# _merge_nodes 0.009859323501586914
# _update_merge_graph 0.019928932189941406
# _find_lowest_cost_edges 0.003061532974243164
# --------- step:  141 ---------
# _merge_nodes 0.007360219955444336
# _update_merge_graph 0.02315664291381836
# _find_lowest_cost_edges 0.0027768611907958984
# --------- step:  142 ---------
# _merge_nodes 0.01382899284362793
# _update_merge_graph 0.01996755599975586
# _find_lowest_cost_edges 0.0030660629272460938
# --------- step:  143 ---------
# _merge_nodes 0.007578849792480469
# _update_merge_graph 0.020138263702392578
# _find_lowest_cost_edges 0.002988100051879883
# --------- step:  144 ---------
# _merge_nodes 0.007114410400390625
# _update_merge_graph 0.02073526382446289
# _find_lowest_cost_edges 0.0029647350311279297
# --------- step:  145 ---------
# _merge_nodes 0.007001161575317383
# _update_merge_graph 0.020434856414794922
# _find_lowest_cost_edges 0.003187894821166992
# --------- step:  146 ---------
# _merge_nodes 0.007385730743408203
# _update_merge_graph 0.023369789123535156
# _find_lowest_cost_edges 0.0019500255584716797
# --------- step:  147 ---------
# _merge_nodes 0.007859945297241211
# _update_merge_graph 0.02051377296447754
# _find_lowest_cost_edges 0.003000020980834961
# --------- step:  148 ---------
# _merge_nodes 0.007374286651611328
# _update_merge_graph 0.024479150772094727
# _find_lowest_cost_edges 0.0026934146881103516
# --------- step:  149 ---------
# _merge_nodes 0.010087013244628906
# _update_merge_graph 0.023722410202026367
# _find_lowest_cost_edges 0.0026454925537109375
# --------- step:  150 ---------
# _merge_nodes 0.009507417678833008
# _update_merge_graph 0.02026844024658203
# _find_lowest_cost_edges 0.0031731128692626953
# --------- step:  151 ---------
# _merge_nodes 0.006760120391845703
# _update_merge_graph 0.02181863784790039
# _find_lowest_cost_edges 0.0027360916137695312
# --------- step:  152 ---------
# _merge_nodes 0.007770538330078125
# _update_merge_graph 0.01975083351135254
# _find_lowest_cost_edges 0.0032711029052734375
# --------- step:  153 ---------
# _merge_nodes 0.0073239803314208984
# _update_merge_graph 0.023415803909301758
# _find_lowest_cost_edges 0.0019073486328125
# --------- step:  154 ---------
# _merge_nodes 0.0075855255126953125
# _update_merge_graph 0.0204620361328125
# _find_lowest_cost_edges 0.003120899200439453
# --------- step:  155 ---------
# _merge_nodes 0.006909370422363281
# _update_merge_graph 0.019980669021606445
# _find_lowest_cost_edges 0.0031540393829345703
# --------- step:  156 ---------
# _merge_nodes 0.007283210754394531
# _update_merge_graph 0.022208452224731445
# _find_lowest_cost_edges 0.0029954910278320312
# --------- step:  157 ---------
# _merge_nodes 0.009669303894042969
# _update_merge_graph 0.024013042449951172
# _find_lowest_cost_edges 0.002936840057373047
# --------- step:  158 ---------
# _merge_nodes 0.00687861442565918
# _update_merge_graph 0.020156383514404297
# _find_lowest_cost_edges 0.0028603076934814453
# --------- step:  159 ---------
# _merge_nodes 0.0068242549896240234
# _update_merge_graph 0.020559310913085938
# _find_lowest_cost_edges 0.0029668807983398438
# --------- step:  160 ---------
# _merge_nodes 0.006951808929443359
# _update_merge_graph 0.022413969039916992
# _find_lowest_cost_edges 0.0028791427612304688
# --------- step:  161 ---------
# _merge_nodes 0.009833574295043945
# _update_merge_graph 0.022400856018066406
# _find_lowest_cost_edges 0.002766847610473633
# --------- step:  162 ---------
# _merge_nodes 0.0073163509368896484
# _update_merge_graph 0.02016162872314453
# _find_lowest_cost_edges 0.0030863285064697266
# --------- step:  163 ---------
# _merge_nodes 0.006999492645263672
# _update_merge_graph 0.020656824111938477
# _find_lowest_cost_edges 0.003147125244140625
# --------- step:  164 ---------
# _merge_nodes 0.007349491119384766
# _update_merge_graph 0.01961970329284668
# _find_lowest_cost_edges 0.003230571746826172
# --------- step:  165 ---------
# _merge_nodes 0.007054328918457031
# _update_merge_graph 0.019936561584472656
# _find_lowest_cost_edges 0.003007650375366211
# --------- step:  166 ---------
# _merge_nodes 0.00670313835144043
# _update_merge_graph 0.02405071258544922
# _find_lowest_cost_edges 0.002801179885864258
# --------- step:  167 ---------
# _merge_nodes 0.01104426383972168
# _update_merge_graph 0.020992279052734375
# _find_lowest_cost_edges 0.0025892257690429688
# --------- step:  168 ---------
# _merge_nodes 0.009790658950805664
# _update_merge_graph 0.023500919342041016
# _find_lowest_cost_edges 0.002674102783203125
# --------- step:  169 ---------
# _merge_nodes 0.009363174438476562
# _update_merge_graph 0.02474522590637207
# _find_lowest_cost_edges 0.0027437210083007812
# --------- step:  170 ---------
# _merge_nodes 0.010106563568115234
# _update_merge_graph 0.024392127990722656
# _find_lowest_cost_edges 0.00286865234375
# --------- step:  171 ---------
# _merge_nodes 0.008205890655517578
# _update_merge_graph 0.022721290588378906
# _find_lowest_cost_edges 0.0028984546661376953
# --------- step:  172 ---------
# _merge_nodes 0.00692296028137207
# _update_merge_graph 0.020846128463745117
# _find_lowest_cost_edges 0.0028994083404541016
# --------- step:  173 ---------
# _merge_nodes 0.007132053375244141
# _update_merge_graph 0.02075815200805664
# _find_lowest_cost_edges 0.003103017807006836
# --------- step:  174 ---------
# _merge_nodes 0.007409811019897461
# _update_merge_graph 0.020641803741455078
# _find_lowest_cost_edges 0.0032715797424316406
# --------- step:  175 ---------
# _merge_nodes 0.007452249526977539
# _update_merge_graph 0.020789146423339844
# _find_lowest_cost_edges 0.002475261688232422
# --------- step:  176 ---------
# _merge_nodes 0.008435964584350586
# _update_merge_graph 0.021963834762573242
# _find_lowest_cost_edges 0.002988576889038086
# --------- step:  177 ---------
# _merge_nodes 0.007242918014526367
# _update_merge_graph 0.02109241485595703
# _find_lowest_cost_edges 0.003088235855102539
# --------- step:  178 ---------
# _merge_nodes 0.00717473030090332
# _update_merge_graph 0.023682117462158203
# _find_lowest_cost_edges 0.0028905868530273438
# --------- step:  179 ---------
# _merge_nodes 0.010062456130981445
# _update_merge_graph 0.023905038833618164
# _find_lowest_cost_edges 0.0028901100158691406
# --------- step:  180 ---------
# _merge_nodes 0.008065223693847656
# _update_merge_graph 0.022632598876953125
# _find_lowest_cost_edges 0.0027463436126708984
# --------- step:  181 ---------
# _merge_nodes 0.007439136505126953
# _update_merge_graph 0.021297931671142578
# _find_lowest_cost_edges 0.0031816959381103516
# --------- step:  182 ---------
# _merge_nodes 0.007377147674560547
# _update_merge_graph 0.02298140525817871
# _find_lowest_cost_edges 0.0032155513763427734
# --------- step:  183 ---------
# _merge_nodes 0.0076749324798583984
# _update_merge_graph 0.02189803123474121
# _find_lowest_cost_edges 0.002889394760131836
# --------- step:  184 ---------
# _merge_nodes 0.007950305938720703
# _update_merge_graph 0.02554631233215332
# _find_lowest_cost_edges 0.0030999183654785156
# --------- step:  185 ---------
# _merge_nodes 0.011289596557617188
# _update_merge_graph 0.02526378631591797
# _find_lowest_cost_edges 0.002928018569946289
# --------- step:  186 ---------
# _merge_nodes 0.007856369018554688
# _update_merge_graph 0.021245479583740234
# _find_lowest_cost_edges 0.0033409595489501953
# --------- step:  187 ---------
# _merge_nodes 0.007941484451293945
# _update_merge_graph 0.021917343139648438
# _find_lowest_cost_edges 0.002959012985229492
# --------- step:  188 ---------
# _merge_nodes 0.007702827453613281
# _update_merge_graph 0.024720191955566406
# _find_lowest_cost_edges 0.0034198760986328125
# --------- step:  189 ---------
# _merge_nodes 0.007192850112915039
# _update_merge_graph 0.020673513412475586
# _find_lowest_cost_edges 0.003310680389404297
# --------- step:  190 ---------
# _merge_nodes 0.007294893264770508
# _update_merge_graph 0.023560285568237305
# _find_lowest_cost_edges 0.0011167526245117188
# --------- step:  191 ---------
# _merge_nodes 0.008716821670532227
# _update_merge_graph 0.025948524475097656
# _find_lowest_cost_edges 0.0034406185150146484
# --------- step:  192 ---------
# _merge_nodes 0.009299039840698242
# _update_merge_graph 0.022648334503173828
# _find_lowest_cost_edges 0.0030574798583984375
# --------- step:  193 ---------
# _merge_nodes 0.007138252258300781
# _update_merge_graph 0.020284652709960938
# _find_lowest_cost_edges 0.003044605255126953
# --------- step:  194 ---------
# _merge_nodes 0.006865501403808594
# _update_merge_graph 0.021149635314941406
# _find_lowest_cost_edges 0.003167867660522461
# --------- step:  195 ---------
# _merge_nodes 0.00681757926940918
# _update_merge_graph 0.02137470245361328
# _find_lowest_cost_edges 0.003194570541381836
# --------- step:  196 ---------
# _merge_nodes 0.020011425018310547
# _update_merge_graph 0.02164912223815918
# _find_lowest_cost_edges 0.0029234886169433594
# --------- step:  197 ---------
# _merge_nodes 0.009918689727783203
# _update_merge_graph 0.025124311447143555
# _find_lowest_cost_edges 0.003010272979736328
# --------- step:  198 ---------
# _merge_nodes 0.011718034744262695
# _update_merge_graph 0.03114938735961914
# _find_lowest_cost_edges 0.002469301223754883
# --------- step:  199 ---------
# _merge_nodes 0.0073969364166259766
# _update_merge_graph 0.029071331024169922
# _find_lowest_cost_edges 0.0031147003173828125
# --------- step:  200 ---------
# _merge_nodes 0.009274721145629883
# _update_merge_graph 0.023571014404296875
# _find_lowest_cost_edges 0.003301382064819336
# --------- step:  201 ---------
# _merge_nodes 0.0073473453521728516
# _update_merge_graph 0.020662546157836914
# _find_lowest_cost_edges 0.003208637237548828
# --------- step:  202 ---------
# _merge_nodes 0.007293224334716797
# _update_merge_graph 0.020950794219970703
# _find_lowest_cost_edges 0.003046751022338867
# --------- step:  203 ---------
# _merge_nodes 0.0070648193359375
# _update_merge_graph 0.020310163497924805
# _find_lowest_cost_edges 0.0031785964965820312
# --------- step:  204 ---------
# _merge_nodes 0.007104396820068359
# _update_merge_graph 0.0225980281829834
# _find_lowest_cost_edges 0.0036034584045410156
# --------- step:  205 ---------
# _merge_nodes 0.020728588104248047
# _update_merge_graph 0.02446436882019043
# _find_lowest_cost_edges 0.0028345584869384766
# --------- step:  206 ---------
# _merge_nodes 0.0073130130767822266
# _update_merge_graph 0.020679712295532227
# _find_lowest_cost_edges 0.003072023391723633
# --------- step:  207 ---------
# _merge_nodes 0.0072972774505615234
# _update_merge_graph 0.024222850799560547
# _find_lowest_cost_edges 0.0030422210693359375
# --------- step:  208 ---------
# _merge_nodes 0.00837564468383789
# _update_merge_graph 0.023385286331176758
# _find_lowest_cost_edges 0.0033004283905029297
# --------- step:  209 ---------
# _merge_nodes 0.009248971939086914
# _update_merge_graph 0.030196428298950195
# _find_lowest_cost_edges 0.0021963119506835938
# --------- step:  210 ---------
# _merge_nodes 0.016486406326293945
# _update_merge_graph 0.02037978172302246
# _find_lowest_cost_edges 0.0030596256256103516
# --------- step:  211 ---------
# _merge_nodes 0.007289886474609375
# _update_merge_graph 0.021209001541137695
# _find_lowest_cost_edges 0.0029783248901367188
# --------- step:  212 ---------
# _merge_nodes 0.006978750228881836
# _update_merge_graph 0.02138972282409668
# _find_lowest_cost_edges 0.003020763397216797
# --------- step:  213 ---------
# _merge_nodes 0.007867097854614258
# _update_merge_graph 0.022797822952270508
# _find_lowest_cost_edges 0.0028629302978515625
# --------- step:  214 ---------
# _merge_nodes 0.008527517318725586
# _update_merge_graph 0.024079084396362305
# _find_lowest_cost_edges 0.002583742141723633
# --------- step:  215 ---------
# _merge_nodes 0.00808405876159668
# _update_merge_graph 0.021044254302978516
# _find_lowest_cost_edges 0.0029625892639160156
# --------- step:  216 ---------
# _merge_nodes 0.007925987243652344
# _update_merge_graph 0.020176410675048828
# _find_lowest_cost_edges 0.002969980239868164
# --------- step:  217 ---------
# _merge_nodes 0.007328033447265625
# _update_merge_graph 0.021213531494140625
# _find_lowest_cost_edges 0.0023119449615478516
# --------- step:  218 ---------
# _merge_nodes 0.01023101806640625
# _update_merge_graph 0.023219823837280273
# _find_lowest_cost_edges 0.002455472946166992
# --------- step:  219 ---------
# _merge_nodes 0.008983612060546875
# _update_merge_graph 0.021306991577148438
# _find_lowest_cost_edges 0.0027618408203125
# --------- step:  220 ---------
# _merge_nodes 0.007020711898803711
# _update_merge_graph 0.020636320114135742
# _find_lowest_cost_edges 0.0027365684509277344
# --------- step:  221 ---------
# _merge_nodes 0.0072252750396728516
# _update_merge_graph 0.02125859260559082
# _find_lowest_cost_edges 0.003007650375366211
# --------- step:  222 ---------
# _merge_nodes 0.0068013668060302734
# _update_merge_graph 0.02198481559753418
# _find_lowest_cost_edges 0.002489328384399414
# --------- step:  223 ---------
# _merge_nodes 0.008733034133911133
# _update_merge_graph 0.020665407180786133
# _find_lowest_cost_edges 0.0028035640716552734
# --------- step:  224 ---------
# _merge_nodes 0.006689310073852539
# _update_merge_graph 0.019826412200927734
# _find_lowest_cost_edges 0.003165721893310547
# --------- step:  225 ---------
# _merge_nodes 0.009316205978393555
# _update_merge_graph 0.02099752426147461
# _find_lowest_cost_edges 0.0029609203338623047
# --------- step:  226 ---------
# _merge_nodes 0.006815910339355469
# _update_merge_graph 0.02065873146057129
# _find_lowest_cost_edges 0.0030515193939208984
# --------- step:  227 ---------
# _merge_nodes 0.0076122283935546875
# _update_merge_graph 0.022220849990844727
# _find_lowest_cost_edges 0.002485513687133789
# --------- step:  228 ---------
# _merge_nodes 0.007247447967529297
# _update_merge_graph 0.021884679794311523
# _find_lowest_cost_edges 0.0029764175415039062
# --------- step:  229 ---------
# _merge_nodes 0.006535053253173828
# _update_merge_graph 0.020915746688842773
# _find_lowest_cost_edges 0.002927064895629883
# --------- step:  230 ---------
# _merge_nodes 0.007306575775146484
# _update_merge_graph 0.02086162567138672
# _find_lowest_cost_edges 0.002880573272705078
# --------- step:  231 ---------
# _merge_nodes 0.007233381271362305
# _update_merge_graph 0.02271723747253418
# _find_lowest_cost_edges 0.00290679931640625
# --------- step:  232 ---------
# _merge_nodes 0.007079124450683594
# _update_merge_graph 0.024232149124145508
# _find_lowest_cost_edges 0.002250194549560547
# --------- step:  233 ---------
# _merge_nodes 0.012574434280395508
# _update_merge_graph 0.022127389907836914
# _find_lowest_cost_edges 0.0029544830322265625
# --------- step:  234 ---------
# _merge_nodes 0.008977890014648438
# _update_merge_graph 0.021391630172729492
# _find_lowest_cost_edges 0.0032134056091308594
# --------- step:  235 ---------
# _merge_nodes 0.007213592529296875
# _update_merge_graph 0.02037978172302246
# _find_lowest_cost_edges 0.003107309341430664
# --------- step:  236 ---------
# _merge_nodes 0.007529497146606445
# _update_merge_graph 0.020427227020263672
# _find_lowest_cost_edges 0.0031578540802001953
# --------- step:  237 ---------
# _merge_nodes 0.007188081741333008
# _update_merge_graph 0.021434307098388672
# _find_lowest_cost_edges 0.002892732620239258
# --------- step:  238 ---------
# _merge_nodes 0.007947444915771484
# _update_merge_graph 0.020111799240112305
# _find_lowest_cost_edges 0.003157377243041992
# --------- step:  239 ---------
# _merge_nodes 0.0073089599609375
# _update_merge_graph 0.020550966262817383
# _find_lowest_cost_edges 0.0027866363525390625
# --------- step:  240 ---------
# _merge_nodes 0.007056474685668945
# _update_merge_graph 0.02055072784423828
# _find_lowest_cost_edges 0.003129720687866211
# --------- step:  241 ---------
# _merge_nodes 0.008004188537597656
# _update_merge_graph 0.02223825454711914
# _find_lowest_cost_edges 0.0025224685668945312
# --------- step:  242 ---------
# _merge_nodes 0.011474847793579102
# _update_merge_graph 0.021648645401000977
# _find_lowest_cost_edges 0.002714395523071289
# --------- step:  243 ---------
# _merge_nodes 0.00904226303100586
# _update_merge_graph 0.021441221237182617
# _find_lowest_cost_edges 0.002806425094604492
# --------- step:  244 ---------
# _merge_nodes 0.007021188735961914
# _update_merge_graph 0.021396398544311523
# _find_lowest_cost_edges 0.002953767776489258
# --------- step:  245 ---------
# _merge_nodes 0.007675886154174805
# _update_merge_graph 0.021759510040283203
# _find_lowest_cost_edges 0.002976655960083008
# --------- step:  246 ---------
# _merge_nodes 0.006683349609375
# _update_merge_graph 0.020753860473632812
# _find_lowest_cost_edges 0.0031168460845947266
# --------- step:  247 ---------
# _merge_nodes 0.006875753402709961
# _update_merge_graph 0.022144079208374023
# _find_lowest_cost_edges 0.0019409656524658203
# --------- step:  248 ---------
# _merge_nodes 0.007720947265625
# _update_merge_graph 0.02059483528137207
# _find_lowest_cost_edges 0.0025658607482910156
# --------- step:  249 ---------
# _merge_nodes 0.007222652435302734
# _update_merge_graph 0.020701169967651367
# _find_lowest_cost_edges 0.0032389163970947266
# --------- step:  250 ---------
# _merge_nodes 0.007252216339111328
# _update_merge_graph 0.019963979721069336
# _find_lowest_cost_edges 0.002974271774291992
# --------- step:  251 ---------
# _merge_nodes 0.007405757904052734
# _update_merge_graph 0.02226424217224121
# _find_lowest_cost_edges 0.002750873565673828
# --------- step:  252 ---------
# _merge_nodes 0.010233402252197266
# _update_merge_graph 0.023958444595336914
# _find_lowest_cost_edges 0.002180337905883789
# --------- step:  253 ---------
# _merge_nodes 0.007829666137695312
# _update_merge_graph 0.021498441696166992
# _find_lowest_cost_edges 0.002894878387451172
# --------- step:  254 ---------
# _merge_nodes 0.008151769638061523
# _update_merge_graph 0.02111363410949707
# _find_lowest_cost_edges 0.002978801727294922
# --------- step:  255 ---------
# _merge_nodes 0.007425785064697266
# _update_merge_graph 0.021687030792236328
# _find_lowest_cost_edges 0.0030782222747802734
# --------- step:  256 ---------
# _merge_nodes 0.01239156723022461
# _update_merge_graph 0.027693986892700195
# _find_lowest_cost_edges 0.00290679931640625
# --------- step:  257 ---------
# _merge_nodes 0.007302999496459961
# _update_merge_graph 0.0258939266204834
# _find_lowest_cost_edges 0.0019450187683105469
# --------- step:  258 ---------
# _merge_nodes 0.010187625885009766
# _update_merge_graph 0.023212432861328125
# _find_lowest_cost_edges 0.003090381622314453
# --------- step:  259 ---------
# _merge_nodes 0.0070650577545166016
# _update_merge_graph 0.02030467987060547
# _find_lowest_cost_edges 0.003027677536010742
# --------- step:  260 ---------
# _merge_nodes 0.00677037239074707
# _update_merge_graph 0.019980192184448242
# _find_lowest_cost_edges 0.0030460357666015625
# --------- step:  261 ---------
# _merge_nodes 0.008653402328491211
# _update_merge_graph 0.02040243148803711
# _find_lowest_cost_edges 0.002641439437866211
# --------- step:  262 ---------
# _merge_nodes 0.010234832763671875
# _update_merge_graph 0.021517038345336914
# _find_lowest_cost_edges 0.002927541732788086
# --------- step:  263 ---------
# _merge_nodes 0.00699925422668457
# _update_merge_graph 0.024712562561035156
# _find_lowest_cost_edges 0.0031337738037109375
# --------- step:  264 ---------
# _merge_nodes 0.008244514465332031
# _update_merge_graph 0.02101922035217285
# _find_lowest_cost_edges 0.002863168716430664
# --------- step:  265 ---------
# _merge_nodes 0.007256746292114258
# _update_merge_graph 0.020483970642089844
# _find_lowest_cost_edges 0.002865314483642578
# --------- step:  266 ---------
# _merge_nodes 0.007281064987182617
# _update_merge_graph 0.02268385887145996
# _find_lowest_cost_edges 0.0024840831756591797
# --------- step:  267 ---------
# _merge_nodes 0.008512258529663086
# _update_merge_graph 0.02114081382751465
# _find_lowest_cost_edges 0.0028543472290039062
# --------- step:  268 ---------
# _merge_nodes 0.007086038589477539
# _update_merge_graph 0.021653413772583008
# _find_lowest_cost_edges 0.0028417110443115234
# --------- step:  269 ---------
# _merge_nodes 0.008132696151733398
# _update_merge_graph 0.022804737091064453
# _find_lowest_cost_edges 0.003223896026611328
# --------- step:  270 ---------
# _merge_nodes 0.007854223251342773
# _update_merge_graph 0.021321535110473633
# _find_lowest_cost_edges 0.0029909610748291016
# --------- step:  271 ---------
# _merge_nodes 0.007995367050170898
# _update_merge_graph 0.022337913513183594
# _find_lowest_cost_edges 0.002454996109008789
# --------- step:  272 ---------
# _merge_nodes 0.007750988006591797
# _update_merge_graph 0.020981311798095703
# _find_lowest_cost_edges 0.0027925968170166016
# --------- step:  273 ---------
# _merge_nodes 0.006871938705444336
# _update_merge_graph 0.02139568328857422
# _find_lowest_cost_edges 0.003072500228881836
# --------- step:  274 ---------
# _merge_nodes 0.0073206424713134766
# _update_merge_graph 0.021268129348754883
# _find_lowest_cost_edges 0.002878427505493164
# --------- step:  275 ---------
# _merge_nodes 0.007213592529296875
# _update_merge_graph 0.02140522003173828
# _find_lowest_cost_edges 0.002896547317504883
# --------- step:  276 ---------
# _merge_nodes 0.007433652877807617
# _update_merge_graph 0.02197575569152832
# _find_lowest_cost_edges 0.0029354095458984375
# --------- step:  277 ---------
# _merge_nodes 0.010498285293579102
# _update_merge_graph 0.020796775817871094
# _find_lowest_cost_edges 0.00284576416015625
# --------- step:  278 ---------
# _merge_nodes 0.00690913200378418
# _update_merge_graph 0.020455121994018555
# _find_lowest_cost_edges 0.003005504608154297
# --------- step:  279 ---------
# _merge_nodes 0.009796619415283203
# _update_merge_graph 0.025235891342163086
# _find_lowest_cost_edges 0.0025548934936523438
# --------- step:  280 ---------
# _merge_nodes 0.01074528694152832
# _update_merge_graph 0.025600194931030273
# _find_lowest_cost_edges 0.0027093887329101562
# --------- step:  281 ---------
# _merge_nodes 0.007269859313964844
# _update_merge_graph 0.0202789306640625
# _find_lowest_cost_edges 0.002780437469482422
# --------- step:  282 ---------
# _merge_nodes 0.007562160491943359
# _update_merge_graph 0.02188730239868164
# _find_lowest_cost_edges 0.0028586387634277344
# --------- step:  283 ---------
# _merge_nodes 0.007285118103027344
# _update_merge_graph 0.027001619338989258
# _find_lowest_cost_edges 0.0018486976623535156
# --------- step:  284 ---------
# _merge_nodes 0.018560409545898438
# _update_merge_graph 0.03125762939453125
# _find_lowest_cost_edges 0.00308990478515625
# --------- step:  285 ---------
# _merge_nodes 0.01008749008178711
# _update_merge_graph 0.022335052490234375
# _find_lowest_cost_edges 0.002888917922973633
# --------- step:  286 ---------
# _merge_nodes 0.010325193405151367
# _update_merge_graph 0.02458357810974121
# _find_lowest_cost_edges 0.002745389938354492
# --------- step:  287 ---------
# _merge_nodes 0.010091066360473633
# _update_merge_graph 0.02335643768310547
# _find_lowest_cost_edges 0.003068685531616211
# --------- step:  288 ---------
# _merge_nodes 0.006547689437866211
# _update_merge_graph 0.022247314453125
# _find_lowest_cost_edges 0.002931356430053711
# --------- step:  289 ---------
# _merge_nodes 0.008133172988891602
# _update_merge_graph 0.023641347885131836
# _find_lowest_cost_edges 0.002959012985229492
# --------- step:  290 ---------
# _merge_nodes 0.0074994564056396484
# _update_merge_graph 0.020167112350463867
# _find_lowest_cost_edges 0.0029218196868896484
# --------- step:  291 ---------
# _merge_nodes 0.006802797317504883
# _update_merge_graph 0.022801876068115234
# _find_lowest_cost_edges 0.002249479293823242
# --------- step:  292 ---------
# _merge_nodes 0.011101722717285156
# _update_merge_graph 0.020300626754760742
# _find_lowest_cost_edges 0.0029163360595703125
# --------- step:  293 ---------
# _merge_nodes 0.008195161819458008
# _update_merge_graph 0.021077394485473633
# _find_lowest_cost_edges 0.002285003662109375
# --------- step:  294 ---------
# _merge_nodes 0.008540153503417969
# _update_merge_graph 0.022769927978515625
# _find_lowest_cost_edges 0.0028426647186279297
# --------- step:  295 ---------
# _merge_nodes 0.007422685623168945
# _update_merge_graph 0.020215988159179688
# _find_lowest_cost_edges 0.002997875213623047
# --------- step:  296 ---------
# _merge_nodes 0.006719827651977539
# _update_merge_graph 0.019913673400878906
# _find_lowest_cost_edges 0.0029058456420898438
# --------- step:  297 ---------
# _merge_nodes 0.007326364517211914
# _update_merge_graph 0.020969152450561523
# _find_lowest_cost_edges 0.00295257568359375
# --------- step:  298 ---------
# _merge_nodes 0.007046699523925781
# _update_merge_graph 0.02065587043762207
# _find_lowest_cost_edges 0.003056049346923828
# --------- step:  299 ---------
# _merge_nodes 0.007572650909423828
# _update_merge_graph 0.02038264274597168
# _find_lowest_cost_edges 0.0028138160705566406
# --------- step:  300 ---------
# _merge_nodes 0.00725102424621582
# _update_merge_graph 0.021286964416503906
# _find_lowest_cost_edges 0.002912282943725586
# --------- step:  301 ---------
# _merge_nodes 0.006975889205932617
# _update_merge_graph 0.02033519744873047
# _find_lowest_cost_edges 0.0029861927032470703
# --------- step:  302 ---------
# _merge_nodes 0.007938623428344727
# _update_merge_graph 0.019705533981323242
# _find_lowest_cost_edges 0.0031905174255371094
# --------- step:  303 ---------
# _merge_nodes 0.007536649703979492
# _update_merge_graph 0.020370006561279297
# _find_lowest_cost_edges 0.0024237632751464844
# --------- step:  304 ---------
# _merge_nodes 0.00883626937866211
# _update_merge_graph 0.020154476165771484
# _find_lowest_cost_edges 0.002840757369995117
# --------- step:  305 ---------
# _merge_nodes 0.007297039031982422
# _update_merge_graph 0.021296262741088867
# _find_lowest_cost_edges 0.002763509750366211
# --------- step:  306 ---------
# _merge_nodes 0.007883071899414062
# _update_merge_graph 0.019988298416137695
# _find_lowest_cost_edges 0.002816915512084961
# --------- step:  307 ---------
# _merge_nodes 0.007291078567504883
# ...
# _merge_nodes 0.008346796035766602
# _update_merge_graph 0.021233320236206055
# _find_lowest_cost_edges 0.0022754669189453125
# --------- step:  401 ---------
# _merge_nodes 0.008168935775756836
# _update_merge_graph 0.023036479949951172
# _find_lowest_cost_edges 0.0022306442260742188
# --------- step:  402 ---------
# _merge_nodes 0.007025003433227539
# _update_merge_graph 0.020786762237548828
# _find_lowest_cost_edges 0.0028085708618164062
# --------- step:  403 ---------
# _merge_nodes 0.008083105087280273
# _update_merge_graph 0.022832155227661133
# _find_lowest_cost_edges 0.0023276805877685547
# --------- step:  404 ---------
# _merge_nodes 0.007992982864379883
# _update_merge_graph 0.03422141075134277
# _find_lowest_cost_edges 0.0015864372253417969
# --------- step:  405 ---------
# _merge_nodes 0.01912212371826172
# _update_merge_graph 0.02159428596496582
# _find_lowest_cost_edges 0.001840829849243164
# --------- step:  406 ---------
# _merge_nodes 0.007256269454956055
# _update_merge_graph 0.020578861236572266
# _find_lowest_cost_edges 0.002064228057861328
# --------- step:  407 ---------
# _merge_nodes 0.00734257698059082
# _update_merge_graph 0.02025437355041504
# _find_lowest_cost_edges 0.0023565292358398438
# --------- step:  408 ---------
# _merge_nodes 0.007943868637084961
# _update_merge_graph 0.020951271057128906
# _find_lowest_cost_edges 0.0026628971099853516
# --------- step:  409 ---------
# _merge_nodes 0.006930828094482422
# _update_merge_graph 0.02010941505432129
# _find_lowest_cost_edges 0.0024709701538085938
# --------- step:  410 ---------
# _merge_nodes 0.007228851318359375
# _update_merge_graph 0.021346569061279297
# _find_lowest_cost_edges 0.0022940635681152344
# --------- step:  411 ---------
# _merge_nodes 0.009366035461425781
# _update_merge_graph 0.019878864288330078
# _find_lowest_cost_edges 0.0025463104248046875
# --------- step:  412 ---------
# _merge_nodes 0.00677180290222168
# _update_merge_graph 0.0193326473236084
# _find_lowest_cost_edges 0.0025544166564941406
# --------- step:  413 ---------
# _merge_nodes 0.008166790008544922
# _update_merge_graph 0.019222259521484375
# _find_lowest_cost_edges 0.0025005340576171875
# --------- step:  414 ---------
# _merge_nodes 0.007018089294433594
# _update_merge_graph 0.019144773483276367
# _find_lowest_cost_edges 0.0024673938751220703
# --------- step:  415 ---------
# _merge_nodes 0.006913185119628906
# _update_merge_graph 0.021329641342163086
# _find_lowest_cost_edges 0.002094268798828125
# --------- step:  416 ---------
# _merge_nodes 0.011275291442871094
# _update_merge_graph 0.022196292877197266
# _find_lowest_cost_edges 0.0023145675659179688
# --------- step:  417 ---------
# _merge_nodes 0.008066892623901367
# _update_merge_graph 0.019394397735595703
# _find_lowest_cost_edges 0.002521038055419922
# --------- step:  418 ---------
# _merge_nodes 0.007775068283081055
# _update_merge_graph 0.023602008819580078
# _find_lowest_cost_edges 0.0022745132446289062
# --------- step:  419 ---------
# _merge_nodes 0.008025646209716797
# _update_merge_graph 0.029404878616333008
# _find_lowest_cost_edges 0.0018413066864013672
# --------- step:  420 ---------
# _merge_nodes 0.008303642272949219
# _update_merge_graph 0.020049095153808594
# _find_lowest_cost_edges 0.0023529529571533203
# --------- step:  421 ---------
# _merge_nodes 0.0077915191650390625
# _update_merge_graph 0.0233156681060791
# _find_lowest_cost_edges 0.0024003982543945312
# --------- step:  422 ---------
# _merge_nodes 0.007414817810058594
# _update_merge_graph 0.02023172378540039
# _find_lowest_cost_edges 0.002469778060913086
# --------- step:  423 ---------
# _merge_nodes 0.008004188537597656
# _update_merge_graph 0.020171642303466797
# _find_lowest_cost_edges 0.002315044403076172
# --------- step:  424 ---------
# _merge_nodes 0.0076105594635009766
# _update_merge_graph 0.024120569229125977
# _find_lowest_cost_edges 0.002078533172607422
# --------- step:  425 ---------
# _merge_nodes 0.008095026016235352
# _update_merge_graph 0.021048307418823242
# _find_lowest_cost_edges 0.0021598339080810547
# --------- step:  426 ---------
# _merge_nodes 0.008538246154785156
# _update_merge_graph 0.020743608474731445
# _find_lowest_cost_edges 0.002244710922241211
# --------- step:  427 ---------
# _merge_nodes 0.008175849914550781
# _update_merge_graph 0.019446611404418945
# _find_lowest_cost_edges 0.002353668212890625
# --------- step:  428 ---------
# _merge_nodes 0.007039070129394531
# _update_merge_graph 0.020107746124267578
# _find_lowest_cost_edges 0.0022139549255371094
# --------- step:  429 ---------
# _merge_nodes 0.008077383041381836
# _update_merge_graph 0.023344755172729492
# _find_lowest_cost_edges 0.0021109580993652344
# --------- step:  430 ---------
# _merge_nodes 0.010954856872558594
# _update_merge_graph 0.02286052703857422
# _find_lowest_cost_edges 0.0021708011627197266
# --------- step:  431 ---------
# _merge_nodes 0.00986790657043457
# _update_merge_graph 0.019243717193603516
# _find_lowest_cost_edges 0.002841949462890625
# --------- step:  432 ---------
# _merge_nodes 0.007235527038574219
# _update_merge_graph 0.019369840621948242
# _find_lowest_cost_edges 0.002396106719970703
# --------- step:  433 ---------
# _merge_nodes 0.006785392761230469
# _update_merge_graph 0.01910090446472168
# _find_lowest_cost_edges 0.002350330352783203
# --------- step:  434 ---------
# _merge_nodes 0.0069844722747802734
# _update_merge_graph 0.02051830291748047
# _find_lowest_cost_edges 0.002325773239135742
# --------- step:  435 ---------
# _merge_nodes 0.009490728378295898
# _update_merge_graph 0.020561933517456055
# _find_lowest_cost_edges 0.0021293163299560547
# --------- step:  436 ---------
# _merge_nodes 0.008253097534179688
# _update_merge_graph 0.020489931106567383
# _find_lowest_cost_edges 0.0022399425506591797
# --------- step:  437 ---------
# _merge_nodes 0.010548591613769531
# _update_merge_graph 0.020821809768676758
# _find_lowest_cost_edges 0.0022623538970947266
# --------- step:  438 ---------
# _merge_nodes 0.007761955261230469
# _update_merge_graph 0.019953250885009766
# _find_lowest_cost_edges 0.0021266937255859375
# --------- step:  439 ---------
# _merge_nodes 0.008475780487060547
# _update_merge_graph 0.030910730361938477
# _find_lowest_cost_edges 0.000850677490234375
# --------- step:  440 ---------
# _merge_nodes 0.007514238357543945
# _update_merge_graph 0.02035379409790039
# _find_lowest_cost_edges 0.0020067691802978516
# --------- step:  441 ---------
# _merge_nodes 0.021855592727661133
# _update_merge_graph 0.029455900192260742
# _find_lowest_cost_edges 0.0021355152130126953
# --------- step:  442 ---------
# _merge_nodes 0.007484912872314453
# _update_merge_graph 0.0179288387298584
# _find_lowest_cost_edges 0.0025589466094970703
# --------- step:  443 ---------
# _merge_nodes 0.006964921951293945
# _update_merge_graph 0.019738197326660156
# _find_lowest_cost_edges 0.0024390220642089844
# --------- step:  444 ---------
# _merge_nodes 0.00852346420288086
# _update_merge_graph 0.024013996124267578
# _find_lowest_cost_edges 0.0021734237670898438
# --------- step:  445 ---------
# _merge_nodes 0.007608175277709961
# _update_merge_graph 0.019292593002319336
# _find_lowest_cost_edges 0.0023725032806396484
# --------- step:  446 ---------
# _merge_nodes 0.007977008819580078
# _update_merge_graph 0.019114017486572266
# _find_lowest_cost_edges 0.002155303955078125
# --------- step:  447 ---------
# _merge_nodes 0.0077152252197265625
# _update_merge_graph 0.018782615661621094
# _find_lowest_cost_edges 0.002164125442504883
# --------- step:  448 ---------
# _merge_nodes 0.0068852901458740234
# _update_merge_graph 0.019061803817749023
# _find_lowest_cost_edges 0.002368450164794922
# --------- step:  449 ---------
# _merge_nodes 0.008704900741577148
# _update_merge_graph 0.021944284439086914
# _find_lowest_cost_edges 0.0018229484558105469
# --------- step:  450 ---------
# _merge_nodes 0.014104127883911133
# _update_merge_graph 0.03508353233337402
# _find_lowest_cost_edges 0.002006053924560547
# --------- step:  451 ---------
# _merge_nodes 0.009253978729248047
# _update_merge_graph 0.019707202911376953
# _find_lowest_cost_edges 0.002290010452270508
# --------- step:  452 ---------
# _merge_nodes 0.00734257698059082
# _update_merge_graph 0.019109249114990234
# _find_lowest_cost_edges 0.0025789737701416016
# --------- step:  453 ---------
# _merge_nodes 0.007680654525756836
# _update_merge_graph 0.019185543060302734
# _find_lowest_cost_edges 0.0017426013946533203
# --------- step:  454 ---------
# _merge_nodes 0.008113384246826172
# _update_merge_graph 0.019844532012939453
# _find_lowest_cost_edges 0.0017690658569335938
# --------- step:  455 ---------
# _merge_nodes 0.008115768432617188
# _update_merge_graph 0.020619630813598633
# _find_lowest_cost_edges 0.0023522377014160156
# --------- step:  456 ---------
# _merge_nodes 0.0071773529052734375
# _update_merge_graph 0.019593477249145508
# _find_lowest_cost_edges 0.0021686553955078125
# --------- step:  457 ---------
# _merge_nodes 0.007165431976318359
# _update_merge_graph 0.018227338790893555
# _find_lowest_cost_edges 0.0023691654205322266
# --------- step:  458 ---------
# _merge_nodes 0.00696110725402832
# _update_merge_graph 0.023500919342041016
# _find_lowest_cost_edges 0.0010559558868408203
# --------- step:  459 ---------
# _merge_nodes 0.009519815444946289
# _update_merge_graph 0.021742582321166992
# _find_lowest_cost_edges 0.0021393299102783203
# --------- step:  460 ---------
# _merge_nodes 0.006713151931762695
# _update_merge_graph 0.0184476375579834
# _find_lowest_cost_edges 0.002191305160522461
# --------- step:  461 ---------
# _merge_nodes 0.009599924087524414
# _update_merge_graph 0.018331050872802734
# _find_lowest_cost_edges 0.0022535324096679688
# --------- step:  462 ---------
# _merge_nodes 0.008870840072631836
# _update_merge_graph 0.0221250057220459
# _find_lowest_cost_edges 0.0013663768768310547
# --------- step:  463 ---------
# _merge_nodes 0.010287761688232422
# _update_merge_graph 0.02375340461730957
# _find_lowest_cost_edges 0.0016131401062011719
# --------- step:  464 ---------
# _merge_nodes 0.007404804229736328
# _update_merge_graph 0.01970076560974121
# _find_lowest_cost_edges 0.002032756805419922
# --------- step:  465 ---------
# _merge_nodes 0.00865030288696289
# _update_merge_graph 0.020594358444213867
# _find_lowest_cost_edges 0.0023431777954101562
# --------- step:  466 ---------
# _merge_nodes 0.007929563522338867
# _update_merge_graph 0.020181894302368164
# _find_lowest_cost_edges 0.0021715164184570312
# --------- step:  467 ---------
# _merge_nodes 0.007942438125610352
# _update_merge_graph 0.021498680114746094
# _find_lowest_cost_edges 0.0018482208251953125
# --------- step:  468 ---------
# _merge_nodes 0.007778644561767578
# _update_merge_graph 0.01903557777404785
# _find_lowest_cost_edges 0.0017979145050048828
# --------- step:  469 ---------
# _merge_nodes 0.008584737777709961
# _update_merge_graph 0.018612384796142578
# _find_lowest_cost_edges 0.002004384994506836
# --------- step:  470 ---------
# _merge_nodes 0.0070552825927734375
# _update_merge_graph 0.017836570739746094
# _find_lowest_cost_edges 0.0020112991333007812
# --------- step:  471 ---------
# _merge_nodes 0.006706714630126953
# _update_merge_graph 0.021176576614379883
# _find_lowest_cost_edges 0.001863718032836914
# --------- step:  472 ---------
# _merge_nodes 0.010327816009521484
# _update_merge_graph 0.021739959716796875
# _find_lowest_cost_edges 0.0017898082733154297
# --------- step:  473 ---------
# _merge_nodes 0.009782552719116211
# _update_merge_graph 0.021054744720458984
# _find_lowest_cost_edges 0.0016252994537353516
# --------- step:  474 ---------
# _merge_nodes 0.010065793991088867
# _update_merge_graph 0.02022862434387207
# _find_lowest_cost_edges 0.00177764892578125
# --------- step:  475 ---------
# _merge_nodes 0.007909297943115234
# _update_merge_graph 0.0180509090423584
# _find_lowest_cost_edges 0.0022225379943847656
# --------- step:  476 ---------
# _merge_nodes 0.00720524787902832
# _update_merge_graph 0.01790142059326172
# _find_lowest_cost_edges 0.0018687248229980469
# --------- step:  477 ---------
# _merge_nodes 0.007019519805908203
# _update_merge_graph 0.02220749855041504
# _find_lowest_cost_edges 0.0020062923431396484
# --------- step:  478 ---------
# _merge_nodes 0.006825685501098633
# _update_merge_graph 0.017719268798828125
# _find_lowest_cost_edges 0.0019567012786865234
# --------- step:  479 ---------
# _merge_nodes 0.006432533264160156
# _update_merge_graph 0.017593860626220703
# _find_lowest_cost_edges 0.0018134117126464844
# --------- step:  480 ---------
# _merge_nodes 0.007115602493286133
# _update_merge_graph 0.019549846649169922
# _find_lowest_cost_edges 0.0018680095672607422
# --------- step:  481 ---------
# _merge_nodes 0.0066988468170166016
# _update_merge_graph 0.02048969268798828
# _find_lowest_cost_edges 0.001804351806640625
# --------- step:  482 ---------
# _merge_nodes 0.00669097900390625
# _update_merge_graph 0.017736434936523438
# _find_lowest_cost_edges 0.002142667770385742
# --------- step:  483 ---------
# _merge_nodes 0.006714820861816406
# _update_merge_graph 0.017879962921142578
# _find_lowest_cost_edges 0.0018625259399414062
# --------- step:  484 ---------
# _merge_nodes 0.008083343505859375
# _update_merge_graph 0.018875837326049805
# _find_lowest_cost_edges 0.00193023681640625
# --------- step:  485 ---------
# _merge_nodes 0.006848573684692383
# _update_merge_graph 0.017757654190063477
# _find_lowest_cost_edges 0.0017399787902832031
# --------- step:  486 ---------
# _merge_nodes 0.006945610046386719
# _update_merge_graph 0.018831253051757812
# _find_lowest_cost_edges 0.001789093017578125
# --------- step:  487 ---------
# _merge_nodes 0.0074863433837890625
# _update_merge_graph 0.019845962524414062
# _find_lowest_cost_edges 0.002133607864379883
# --------- step:  488 ---------
# _merge_nodes 0.0071794986724853516
# _update_merge_graph 0.017283916473388672
# _find_lowest_cost_edges 0.0020232200622558594
# --------- step:  489 ---------
# _merge_nodes 0.0066030025482177734
# _update_merge_graph 0.01949000358581543
# _find_lowest_cost_edges 0.0017151832580566406
# --------- step:  490 ---------
# _merge_nodes 0.008486509323120117
# _update_merge_graph 0.018777132034301758
# _find_lowest_cost_edges 0.001402139663696289
# --------- step:  491 ---------
# _merge_nodes 0.007504940032958984
# _update_merge_graph 0.017481088638305664
# _find_lowest_cost_edges 0.0017571449279785156
# --------- step:  492 ---------
# _merge_nodes 0.006577968597412109
# _update_merge_graph 0.018220901489257812
# _find_lowest_cost_edges 0.0014569759368896484
# --------- step:  493 ---------
# _merge_nodes 0.006918430328369141
# _update_merge_graph 0.020118236541748047
# _find_lowest_cost_edges 0.0015408992767333984
# --------- step:  494 ---------
# _merge_nodes 0.007687568664550781
# _update_merge_graph 0.017946958541870117
# _find_lowest_cost_edges 0.001837015151977539
# --------- step:  495 ---------
# _merge_nodes 0.010788440704345703
# _update_merge_graph 0.020113229751586914
# _find_lowest_cost_edges 0.0019822120666503906
# --------- step:  496 ---------
# _merge_nodes 0.007998466491699219
# _update_merge_graph 0.019613027572631836
# _find_lowest_cost_edges 0.0014121532440185547
# --------- step:  497 ---------
# _merge_nodes 0.007836580276489258
# _update_merge_graph 0.017592668533325195
# _find_lowest_cost_edges 0.0018463134765625
# --------- step:  498 ---------
# _merge_nodes 0.008060932159423828
# _update_merge_graph 0.0202484130859375
# _find_lowest_cost_edges 0.0015077590942382812
# --------- step:  499 ---------
# _merge_nodes 0.008680105209350586
# _update_merge_graph 0.020958423614501953
# _find_lowest_cost_edges 0.001375436782836914
# --------- step:  500 ---------
# ratio 0.09828674481514878
#
# ========== Run 1 ==========
#
# Original Graph Accuracy:   0.6536
# Coarsened Graph Accuracy:  0.7500
# Inverted Coarsened Accuracy: 0.5869
#
# ========== Run 2 ==========
#
# Original Graph Accuracy:   0.6958
# Coarsened Graph Accuracy:  0.7500
# Inverted Coarsened Accuracy: 0.5827
#
# ========== Run 3 ==========
#
# Original Graph Accuracy:   0.6988
# Coarsened Graph Accuracy:  0.9375
# Inverted Coarsened Accuracy: 0.5648
#
# ========== Run 4 ==========
#
# Original Graph Accuracy:   0.6687
# Coarsened Graph Accuracy:  0.7188
# Inverted Coarsened Accuracy: 0.5556
#
# ========== Run 5 ==========
#
# Original Graph Accuracy:   0.6717
# Coarsened Graph Accuracy:  0.8438
# Inverted Coarsened Accuracy: 0.5576
#
# Original Graph Accuracy:
#   Mean: 0.6777
#   Std:  0.0171
#
# Coarsened Graph Accuracy:
#   Mean: 0.8000
#   Std:  0.0805
#
# Inverted Accuracy:
#   Mean: 0.5695
#   Std:  0.0129

# %%
coarsend_graph
# Out:
# Graph(num_nodes={'paper': 33},
#       num_edges={('paper', 'cited-by', 'paper'): 640, ('paper', 'cites', 'paper'): 640},
#       metagraph=[('paper', 'paper', 'cited-by'), ('paper', 'paper', 'cites')])

# %%
# Import necessary libraries (if not already imported)
import torch
import torch.nn.functional as F
import numpy as np
from Models.GNNs.HGCN import ImprovedHeteroGNN

#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_original = HeteroGCN(in_dim=original_graph.nodes["paper"].data["feat"].shape[1], hidden_dim=64,
                  out_dim=6, rel_names=original_graph.etypes)


feat_orig = {'paper': original_graph.nodes['paper'].data['feat']}

# Use our splits utility
data_splits_orig = get_splits_and_labels(original_graph)
train_idx_orig = data_splits_orig['train_idx']
val_idx_orig = data_splits_orig['val_idx']
test_idx_orig = data_splits_orig['test_idx']
labels_orig = original_graph.nodes['paper'].data['label']

optimizer_original = torch.optim.Adam(model_original.parameters(), lr=0.01, weight_decay=5e-4)



model_coarsened = HeteroGCN(in_dim=coarsend_graph.nodes["paper"].data["feat"].shape[1], hidden_dim=64,
                  out_dim=6, rel_names=original_graph.etypes)


feat_coar = {'paper': coarsend_graph.nodes['paper'].data['feat']}

# Use our splits utility
data_splits_coar = get_splits_and_labels(coarsend_graph)
train_idx_coar = data_splits_coar['train_idx']
val_idx_coar = data_splits_coar['val_idx']
test_idx_coar = data_splits_coar['test_idx']
labels_coar = coarsend_graph.nodes['paper'].data['label']

optimizer_coarsened = torch.optim.Adam(model_coarsened.parameters(), lr=0.01, weight_decay=5e-4)





target_node_type = "paper"



# Function to apply inversion mapping from coarsened to original
def apply_inversion_mapping(coarsened_pred, inversion_map, original_labels, test_mask):
    """
    Maps predictions from coarsened graph back to original graph nodes
    
    Args:
        coarsened_pred: Predictions on coarsened graph
        inversion_map: Mapping from coarsened nodes to original nodes
        original_labels: Ground truth labels of original graph
        
    Returns:
        mapped_accuracy: Accuracy after applying inversion mapping
    """
    correct_count = 0
    total_count = 0
    
    for orig_node, coarsened_node in inversion_map.items():
        if not coarsened_node in test_mask:
            continue
        coarse_pred = coarsened_pred[coarsened_node]
        orig_label = original_labels[orig_node]
        #print(coarse_pred, orig_label)

        correct = (coarse_pred == orig_label)
    
                
        if correct:
            correct_count += 1
     #   else:
      #      print(f"Mismatch: Coarsened Node {coarsened_node} predicted {coarse_pred}, Original Node {orig_node} label {orig_label}")
        total_count += 1
    
    return correct_count / total_count if total_count > 0 else 0

# Training function for original graph
def train_original():
    model_original.train()
    optimizer_original.zero_grad()
    
    #print(original_x_original_data.edge_index_dict)
    logits = model_original(original_graph, feat_orig)['paper']
    loss = F.cross_entropy(logits[train_idx_orig], labels_orig[train_idx_orig])
    loss.backward()
    optimizer_original.step()
    return loss.item()

# Training function for coarsened graph
def train_coarsened():
    model_coarsened.train()
    optimizer_coarsened.zero_grad()
    logits = model_coarsened(coarsend_graph, feat_coar)["paper"]
    loss = F.cross_entropy(logits[train_idx_coar], labels_coar[train_idx_coar])
    
    loss.backward()
    optimizer_coarsened.step()
    return loss.item()

    
# Evaluation function for original graph
def test_original():
    model_original.eval()
    with torch.no_grad():
        logits = model_original(original_graph, feat_orig)
        pred = logits[target_node_type].argmax(dim=1)
        
        # Calculate accuracy on test set
        correct = (pred[val_idx_orig] == labels_orig[val_idx_orig]).sum().item()
        return correct / val_idx_orig.shape[0]

# Evaluation function for coarsened graph
def test_coarsened():
    model_coarsened.eval()
    with torch.no_grad():
        logits = model_original(coarsend_graph, feat_coar)
        pred = logits[target_node_type].argmax(dim=1)
        
        # Calculate accuracy on test set
        correct = (pred[val_idx_coar] == labels_coar[val_idx_coar]).sum().item()
        coarsened_acc =  correct / val_idx_coar.shape[0]
        inverted_acc = 0
        
        # Apply inversion mapping to evaluate how coarsened predictions map to original graph
        inverted_acc  = apply_inversion_mapping(
              pred,  
              mapping,
              original_graph.nodes[target_node_type].data["label"], 
              test_idx_coar
          )
        return coarsened_acc, inverted_acc

# Training for 50 epochs and comparing both models
results = {
    "epoch": [],
    "original_loss": [],
    "coarsened_loss": [],
    "original_acc": [],
    "coarsened_acc": [],
    "inverted_acc": []
}
epochs = 150
for epoch in range(epochs):
    # Train both models
    original_loss = train_original()
    coarsened_loss = train_coarsened()
    
    # Store results
    results["epoch"].append(epoch+1)
    results["original_loss"].append(original_loss)
    results["coarsened_loss"].append(coarsened_loss)
    
    # Evaluate every 10 epochs
    if epoch % 10 == 0:
        original_acc = test_original()
        coarsened_acc, inverted_acc = test_coarsened()
        results["original_acc"].append(original_acc)
        results["coarsened_acc"].append(coarsened_acc)
        results["inverted_acc"].append(inverted_acc)
        
        print(f'Epoch {epoch+1}:')
    
    
        print(f'  Original Graph - Loss: {original_loss:.4f}, Accuracy: {original_acc:.4f}')
        print(f'  Coarsened Graph - Loss: {coarsened_loss:.4f}, Accuracy: {coarsened_acc:.4f}')
        print(f'  Inverted Coarsened - Accuracy: {inverted_acc:.4f}')
        print()

# Visualization of results
import matplotlib.pyplot as plt

# Plot loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(results["epoch"], results["original_loss"], label="Original Graph")
plt.plot(results["epoch"], results["coarsened_loss"], label="Coarsened Graph")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
x = [results["epoch"][i] for i in range(0, epochs, 10)]
plt.plot(x, results["original_acc"], 'o-', label="Original Graph")
plt.plot(x, results["coarsened_acc"], 's-', label="Coarsened Graph")
plt.plot(x, results["inverted_acc"], '^-', label="Inverted Coarsened")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Test Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# Final comparison
print("Final Performance Comparison:")
print(f"Original Graph Accuracy: {results['original_acc'][-1]:.4f}")
print(f"Coarsened Graph Accuracy: {results['coarsened_acc'][-1]:.4f}")
print(f"Inverted Coarsened Accuracy: {results['inverted_acc'][-1]:.4f}")

# Calculate speedup from using coarsened graph
# (You would need to time the training for a proper comparison)
# Out:
# Epoch 1:
#   Original Graph - Loss: 1.7954, Accuracy: 0.2530
#   Coarsened Graph - Loss: 1.7924, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2247
#
# Epoch 11:
#   Original Graph - Loss: 1.6874, Accuracy: 0.5422
#   Coarsened Graph - Loss: 1.1606, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 21:
#   Original Graph - Loss: 1.5403, Accuracy: 0.6024
#   Coarsened Graph - Loss: 1.0897, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 31:
#   Original Graph - Loss: 1.3229, Accuracy: 0.6386
#   Coarsened Graph - Loss: 1.0766, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 41:
#   Original Graph - Loss: 1.0821, Accuracy: 0.6687
#   Coarsened Graph - Loss: 1.0654, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 51:
#   Original Graph - Loss: 0.8761, Accuracy: 0.6898
#   Coarsened Graph - Loss: 1.0536, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 61:
#   Original Graph - Loss: 0.7283, Accuracy: 0.7048
#   Coarsened Graph - Loss: 1.0413, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 71:
#   Original Graph - Loss: 0.6309, Accuracy: 0.7199
#   Coarsened Graph - Loss: 1.0287, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 81:
#   Original Graph - Loss: 0.5675, Accuracy: 0.7199
#   Coarsened Graph - Loss: 1.0159, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 91:
#   Original Graph - Loss: 0.5250, Accuracy: 0.7078
#   Coarsened Graph - Loss: 1.0029, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 101:
#   Original Graph - Loss: 0.4953, Accuracy: 0.7048
#   Coarsened Graph - Loss: 0.9900, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 111:
#   Original Graph - Loss: 0.4743, Accuracy: 0.7018
#   Coarsened Graph - Loss: 0.9771, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 121:
#   Original Graph - Loss: 0.4584, Accuracy: 0.7018
#   Coarsened Graph - Loss: 0.9643, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 131:
#   Original Graph - Loss: 0.4462, Accuracy: 0.6988
#   Coarsened Graph - Loss: 0.9516, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
#
# Epoch 141:
#   Original Graph - Loss: 0.4363, Accuracy: 0.7018
#   Coarsened Graph - Loss: 0.9391, Accuracy: 0.3333
#   Inverted Coarsened - Accuracy: 0.2178
# Final Performance Comparison:
# Original Graph Accuracy: 0.7018
# Coarsened Graph Accuracy: 0.3333
# Inverted Coarsened Accuracy: 0.2178

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid
import numpy as np
import random

# fix global seeds (we'll override per‐run below)
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

class GCN(torch.nn.Module):
    def __init__(self, in_feats, hidden_dim, out_feats, dropout=0.5):
        super().__init__()
        self.conv1 = GCNConv(in_feats, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, out_feats)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return x

def run(seed):
    # reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    # 1) Load Citeseer public split
    dataset = Planetoid(root='data/Citeseer', name='CiteSeer', split='public')
    data = dataset[0].to(device)

    # 2) Model & optimizer (Table 6 hyperparams)
    model = GCN(
        in_feats   = dataset.num_features,
        hidden_dim = 256,
        out_feats  = dataset.num_classes,
        dropout    = 0.5
    ).to(device)
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=1e-2,
        weight_decay=5e-4
    )

    best_val_acc = 0.0
    test_acc_at_best = 0.0

    # 3) Training with early stopping by validation
    for epoch in range(1, 501):
        model.train()
        optimizer.zero_grad()
        out = model(data.x, data.edge_index)
        loss = F.cross_entropy(out[data.train_mask], data.y[data.train_mask])
        loss.backward()
        optimizer.step()

        model.eval()
        logits = model(data.x, data.edge_index)
        preds = logits.argmax(dim=1)

        train_acc = (preds[data.train_mask] == data.y[data.train_mask]).float().mean()
        val_acc   = (preds[data.val_mask]   == data.y[data.val_mask]).float().mean()
        test_acc  = (preds[data.test_mask]  == data.y[data.test_mask]).float().mean()

        # track best
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            test_acc_at_best = test_acc

    return test_acc_at_best.item()

if __name__ == '__main__':
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    seeds = [1, 2, 3, 4, 5]
    results = [run(s) for s in seeds]
    mean = np.mean(results)
    std  = np.std(results)
    print(f'Test accuracy over seeds {seeds}:')
    print([f'{r*100:.2f}%' for r in results])
    print(f'Mean ± std: {mean*100:.2f}% ± {std*100:.2f}%')
# Out:
# Test accuracy over seeds [1, 2, 3, 4, 5]:
# ['68.40%', '69.80%', '70.30%', '68.90%', '68.30%']
# Mean ± std: 69.14% ± 0.79%
